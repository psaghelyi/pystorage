# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [11]</a>'.</span>

# %%
# %pip install numpy pandas seaborn matplotlib
# Out:
# Requirement already satisfied: numpy in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (1.26.1)
# Requirement already satisfied: pandas in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: seaborn in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (0.13.0)
# Requirement already satisfied: matplotlib in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: six>=1.5 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from math import log
import subprocess

num_steps_users = 12  # Number of steps for users
num_steps_sizes = 12  # Number of steps for payload sizes
run_time_seconds = 30  # Number of seconds to run each test
num_workers = 4 # Number of workers to use for each test

payload_sizes = np.unique(np.logspace(0, 20, num=num_steps_sizes, base=2).astype(int))  # Logarithmically spaced sizes, ensure unique values
num_users_list = np.unique(np.logspace(0, 8, num=num_steps_users, base=2).astype(int))  # Logarithmically spaced users, ensure unique values


# fix user, small files between 1byte and 100kb
#min_size_log2 = 0  # log2(1 byte)
#max_size_log2 = log(100 * 1024, 2)  # log2(100 KB)
#num_steps_sizes = 32  # Number of steps for payload sizes
#payload_sizes = np.unique(np.logspace(min_size_log2, max_size_log2, num=num_steps_sizes, base=2).astype(int))
#num_users_list = np.full(1, 500)

# %%
tasks = []
for payload_size in payload_sizes:
    for num_users in num_users_list:
        task = {
            "num_users": num_users,
            "spawn_rate": num_users,  # Adjust as needed
            "payload_size": payload_size,
            "csv_filename": f"results_{payload_size}_{num_users}"
        }
        tasks.append(task)

# View first 5 tasks as an example
tasks_df = pd.DataFrame(tasks)

pd.set_option('display.max_rows', None)
print(tasks_df)
pd.reset_option('display.max_rows')
# Out:
#      num_users  spawn_rate  payload_size         csv_filename
# 0            1           1             1          results_1_1
# 1            2           2             1          results_1_2
# 2            4           4             1          results_1_4
# 3            7           7             1          results_1_7
# 4           12          12             1         results_1_12
# 5           20          20             1         results_1_20
# 6           34          34             1         results_1_34
# 7           56          56             1         results_1_56
# 8           93          93             1         results_1_93
# 9          154         154             1        results_1_154
# 10         256         256             1        results_1_256
# 11           1           1             3          results_3_1
# 12           2           2             3          results_3_2
# 13           4           4             3          results_3_4
# 14           7           7             3          results_3_7
# 15          12          12             3         results_3_12
# 16          20          20             3         results_3_20
# 17          34          34             3         results_3_34
# 18          56          56             3         results_3_56
# 19          93          93             3         results_3_93
# 20         154         154             3        results_3_154
# 21         256         256             3        results_3_256
# 22           1           1            12         results_12_1
# 23           2           2            12         results_12_2
# 24           4           4            12         results_12_4
# 25           7           7            12         results_12_7
# 26          12          12            12        results_12_12
# 27          20          20            12        results_12_20
# 28          34          34            12        results_12_34
# 29          56          56            12        results_12_56
# 30          93          93            12        results_12_93
# 31         154         154            12       results_12_154
# 32         256         256            12       results_12_256
# 33           1           1            43         results_43_1
# 34           2           2            43         results_43_2
# 35           4           4            43         results_43_4
# 36           7           7            43         results_43_7
# 37          12          12            43        results_43_12
# 38          20          20            43        results_43_20
# 39          34          34            43        results_43_34
# 40          56          56            43        results_43_56
# 41          93          93            43        results_43_93
# 42         154         154            43       results_43_154
# 43         256         256            43       results_43_256
# 44           1           1           154        results_154_1
# 45           2           2           154        results_154_2
# 46           4           4           154        results_154_4
# 47           7           7           154        results_154_7
# 48          12          12           154       results_154_12
# 49          20          20           154       results_154_20
# 50          34          34           154       results_154_34
# 51          56          56           154       results_154_56
# 52          93          93           154       results_154_93
# 53         154         154           154      results_154_154
# 54         256         256           154      results_154_256
# 55           1           1           545        results_545_1
# 56           2           2           545        results_545_2
# 57           4           4           545        results_545_4
# 58           7           7           545        results_545_7
# 59          12          12           545       results_545_12
# 60          20          20           545       results_545_20
# 61          34          34           545       results_545_34
# 62          56          56           545       results_545_56
# 63          93          93           545       results_545_93
# 64         154         154           545      results_545_154
# 65         256         256           545      results_545_256
# 66           1           1          1922       results_1922_1
# 67           2           2          1922       results_1922_2
# 68           4           4          1922       results_1922_4
# 69           7           7          1922       results_1922_7
# 70          12          12          1922      results_1922_12
# 71          20          20          1922      results_1922_20
# 72          34          34          1922      results_1922_34
# 73          56          56          1922      results_1922_56
# 74          93          93          1922      results_1922_93
# 75         154         154          1922     results_1922_154
# 76         256         256          1922     results_1922_256
# 77           1           1          6780       results_6780_1
# 78           2           2          6780       results_6780_2
# 79           4           4          6780       results_6780_4
# 80           7           7          6780       results_6780_7
# 81          12          12          6780      results_6780_12
# 82          20          20          6780      results_6780_20
# 83          34          34          6780      results_6780_34
# 84          56          56          6780      results_6780_56
# 85          93          93          6780      results_6780_93
# 86         154         154          6780     results_6780_154
# 87         256         256          6780     results_6780_256
# 88           1           1         23912      results_23912_1
# 89           2           2         23912      results_23912_2
# 90           4           4         23912      results_23912_4
# 91           7           7         23912      results_23912_7
# 92          12          12         23912     results_23912_12
# 93          20          20         23912     results_23912_20
# 94          34          34         23912     results_23912_34
# 95          56          56         23912     results_23912_56
# 96          93          93         23912     results_23912_93
# 97         154         154         23912    results_23912_154
# 98         256         256         23912    results_23912_256
# 99           1           1         84322      results_84322_1
# 100          2           2         84322      results_84322_2
# 101          4           4         84322      results_84322_4
# 102          7           7         84322      results_84322_7
# 103         12          12         84322     results_84322_12
# 104         20          20         84322     results_84322_20
# 105         34          34         84322     results_84322_34
# 106         56          56         84322     results_84322_56
# 107         93          93         84322     results_84322_93
# 108        154         154         84322    results_84322_154
# 109        256         256         84322    results_84322_256
# 110          1           1        297353     results_297353_1
# 111          2           2        297353     results_297353_2
# 112          4           4        297353     results_297353_4
# 113          7           7        297353     results_297353_7
# 114         12          12        297353    results_297353_12
# 115         20          20        297353    results_297353_20
# 116         34          34        297353    results_297353_34
# 117         56          56        297353    results_297353_56
# 118         93          93        297353    results_297353_93
# 119        154         154        297353   results_297353_154
# 120        256         256        297353   results_297353_256
# 121          1           1       1048576    results_1048576_1
# 122          2           2       1048576    results_1048576_2
# 123          4           4       1048576    results_1048576_4
# 124          7           7       1048576    results_1048576_7
# 125         12          12       1048576   results_1048576_12
# 126         20          20       1048576   results_1048576_20
# 127         34          34       1048576   results_1048576_34
# 128         56          56       1048576   results_1048576_56
# 129         93          93       1048576   results_1048576_93
# 130        154         154       1048576  results_1048576_154
# 131        256         256       1048576  results_1048576_256

# %%
# Set the aesthetics for the plot
sns.set(style="whitegrid")

# Create the scatter plot
plt.figure(figsize=(10, 6))
ax = sns.scatterplot(data=tasks_df, x='payload_size', y='num_users', size='num_users', hue='num_users', palette='viridis', sizes=(20, 200))

# Set the scale of the x/y-axis to logarithmic to better visualize the data
ax.set_xscale('log', base=2)
ax.set_yscale('log', base=2)

# Set plot labels and title
ax.set_xlabel('Payload Size (Bytes)')
ax.set_ylabel('Number of Users')
ax.set_title('Number of Users vs Payload Size for Each Task')

# Show the plot
plt.show()

# %%
def run_benchmark_docker(task):
    results_file_path = f"results/{task['csv_filename']}"

    # Check if the results file already exists
    if os.path.exists(f".{results_file_path}_stats.csv"):
        print(f"Skipping benchmark for task: {task} as results already exist.")
        return
    
    # Set environment variables
    os.environ['NUM_USERS'] = str(task['num_users'])
    os.environ['SPAWN_RATE'] = str(task['spawn_rate'])
    os.environ['RUN_TIME'] = str(run_time_seconds)
    os.environ['CSV_FILENAME'] = results_file_path
    os.environ['PAYLOAD_SIZE'] = str(task['payload_size'])
    os.environ['NUM_WORKERS'] = str(num_workers)
    
    # Run the benchmark using Docker Compose
    subprocess.run(["docker", "compose", "up", "--scale", f"locust-worker={num_workers}"], check=True)

    # Optionally, you can stop and remove containers if needed
    subprocess.run(["docker-compose", "down"], check=True)


# Ensure the results directory exists
os.makedirs('.results', exist_ok=True)

#for task in tasks:
#    run_benchmark_docker(task)

# %%
def run_benchmark_local(task):
    results_file_path = f".results/{task['csv_filename']}"

    # Check if the results file already exists
    if os.path.exists(f"{results_file_path}_stats.csv"):
        print(f"Skipping benchmark for task: {task} as results already exist.")
        return
    
    os.environ['PAYLOAD_SIZE'] = str(task['payload_size'])
    os.environ['NUM_WORKERS'] = str(num_workers)
    
    # Command to start the Locust master
    master_command = ["locust", "-f", "../locust/locustfile.py", "--master", "--headless", 
                      "--expect-workers", "4",
                      "--host", "http://192.168.1.105:8000", 
                      "-u", str(task['num_users']), 
                      "-r", str(task['spawn_rate']), 
                      "--run-time", str(run_time_seconds),
                      "--csv", results_file_path]

    # Commands to start Locust workers
    worker_commands = [
        ["locust", "-f", "../locust/locustfile.py", "--worker", "--master-host", "127.0.0.1"] for _ in range(4)
    ]

    # Start the Locust master
    master_process = subprocess.Popen(master_command)

    # Start the worker processes
    worker_processes = [subprocess.Popen(cmd) for cmd in worker_commands]
    
    try:
        # Wait for the master process to complete
        master_process.wait()
    except KeyboardInterrupt:
        # Handle Ctrl+C
        pass
    finally:
        # Terminate all processes
        master_process.terminate()
        for worker in worker_processes:
            worker.terminate()


# Ensure the results directory exists
os.makedirs('.results', exist_ok=True)

for task in tasks:
    run_benchmark_local(task)
# Out:
# Skipping benchmark for task: {'num_users': 1, 'spawn_rate': 1, 'payload_size': 1, 'csv_filename': 'results_1_1'} as results already exist.
# Skipping benchmark for task: {'num_users': 2, 'spawn_rate': 2, 'payload_size': 1, 'csv_filename': 'results_1_2'} as results already exist.
# Skipping benchmark for task: {'num_users': 4, 'spawn_rate': 4, 'payload_size': 1, 'csv_filename': 'results_1_4'} as results already exist.
# Skipping benchmark for task: {'num_users': 7, 'spawn_rate': 7, 'payload_size': 1, 'csv_filename': 'results_1_7'} as results already exist.
# Skipping benchmark for task: {'num_users': 12, 'spawn_rate': 12, 'payload_size': 1, 'csv_filename': 'results_1_12'} as results already exist.
# Skipping benchmark for task: {'num_users': 20, 'spawn_rate': 20, 'payload_size': 1, 'csv_filename': 'results_1_20'} as results already exist.
# Skipping benchmark for task: {'num_users': 34, 'spawn_rate': 34, 'payload_size': 1, 'csv_filename': 'results_1_34'} as results already exist.
# Skipping benchmark for task: {'num_users': 56, 'spawn_rate': 56, 'payload_size': 1, 'csv_filename': 'results_1_56'} as results already exist.
# Skipping benchmark for task: {'num_users': 93, 'spawn_rate': 93, 'payload_size': 1, 'csv_filename': 'results_1_93'} as results already exist.
# Skipping benchmark for task: {'num_users': 154, 'spawn_rate': 154, 'payload_size': 1, 'csv_filename': 'results_1_154'} as results already exist.
# Skipping benchmark for task: {'num_users': 256, 'spawn_rate': 256, 'payload_size': 1, 'csv_filename': 'results_1_256'} as results already exist.
# Skipping benchmark for task: {'num_users': 1, 'spawn_rate': 1, 'payload_size': 3, 'csv_filename': 'results_3_1'} as results already exist.
# Skipping benchmark for task: {'num_users': 2, 'spawn_rate': 2, 'payload_size': 3, 'csv_filename': 'results_3_2'} as results already exist.
# Skipping benchmark for task: {'num_users': 4, 'spawn_rate': 4, 'payload_size': 3, 'csv_filename': 'results_3_4'} as results already exist.
# Skipping benchmark for task: {'num_users': 7, 'spawn_rate': 7, 'payload_size': 3, 'csv_filename': 'results_3_7'} as results already exist.
# Skipping benchmark for task: {'num_users': 12, 'spawn_rate': 12, 'payload_size': 3, 'csv_filename': 'results_3_12'} as results already exist.
# Skipping benchmark for task: {'num_users': 20, 'spawn_rate': 20, 'payload_size': 3, 'csv_filename': 'results_3_20'} as results already exist.
# Skipping benchmark for task: {'num_users': 34, 'spawn_rate': 34, 'payload_size': 3, 'csv_filename': 'results_3_34'} as results already exist.
# Skipping benchmark for task: {'num_users': 56, 'spawn_rate': 56, 'payload_size': 3, 'csv_filename': 'results_3_56'} as results already exist.
# Skipping benchmark for task: {'num_users': 93, 'spawn_rate': 93, 'payload_size': 3, 'csv_filename': 'results_3_93'} as results already exist.
# Skipping benchmark for task: {'num_users': 154, 'spawn_rate': 154, 'payload_size': 3, 'csv_filename': 'results_3_154'} as results already exist.
# Skipping benchmark for task: {'num_users': 256, 'spawn_rate': 256, 'payload_size': 3, 'csv_filename': 'results_3_256'} as results already exist.
# Skipping benchmark for task: {'num_users': 1, 'spawn_rate': 1, 'payload_size': 12, 'csv_filename': 'results_12_1'} as results already exist.
# Skipping benchmark for task: {'num_users': 2, 'spawn_rate': 2, 'payload_size': 12, 'csv_filename': 'results_12_2'} as results already exist.
# Skipping benchmark for task: {'num_users': 4, 'spawn_rate': 4, 'payload_size': 12, 'csv_filename': 'results_12_4'} as results already exist.
# Skipping benchmark for task: {'num_users': 7, 'spawn_rate': 7, 'payload_size': 12, 'csv_filename': 'results_12_7'} as results already exist.
# Skipping benchmark for task: {'num_users': 12, 'spawn_rate': 12, 'payload_size': 12, 'csv_filename': 'results_12_12'} as results already exist.
# Skipping benchmark for task: {'num_users': 20, 'spawn_rate': 20, 'payload_size': 12, 'csv_filename': 'results_12_20'} as results already exist.
# Skipping benchmark for task: {'num_users': 34, 'spawn_rate': 34, 'payload_size': 12, 'csv_filename': 'results_12_34'} as results already exist.
# Skipping benchmark for task: {'num_users': 56, 'spawn_rate': 56, 'payload_size':
93'} as results already exist.
# Skipping benchmark for task: {'num_users': 154, 'spawn_rate': 154, 'payload_size': 84322, 'csv_filename': 'results_84322_154'} as results already exist.
# Skipping benchmark for task: {'num_users': 256, 'spawn_rate': 256, 'payload_size': 84322, 'csv_filename': 'results_84322_256'} as results already exist.
# Skipping benchmark for task: {'num_users': 1, 'spawn_rate': 1, 'payload_size': 297353, 'csv_filename': 'results_297353_1'} as results already exist.
# Skipping benchmark for task: {'num_users': 2, 'spawn_rate': 2, 'payload_size': 297353, 'csv_filename': 'results_297353_2'} as results already exist.
# Skipping benchmark for task: {'num_users': 4, 'spawn_rate': 4, 'payload_size': 297353, 'csv_filename': 'results_297353_4'} as results already exist.
# Skipping benchmark for task: {'num_users': 7, 'spawn_rate': 7, 'payload_size': 297353, 'csv_filename': 'results_297353_7'} as results already exist.
# Skipping benchmark for task: {'num_users': 12, 'spawn_rate': 12, 'payload_size': 297353, 'csv_filename': 'results_297353_12'} as results already exist.
# Skipping benchmark for task: {'num_users': 20, 'spawn_rate': 20, 'payload_size': 297353, 'csv_filename': 'results_297353_20'} as results already exist.
# Skipping benchmark for task: {'num_users': 34, 'spawn_rate': 34, 'payload_size': 297353, 'csv_filename': 'results_297353_34'} as results already exist.
# Skipping benchmark for task: {'num_users': 56, 'spawn_rate': 56, 'payload_size': 297353, 'csv_filename': 'results_297353_56'} as results already exist.
# Skipping benchmark for task: {'num_users': 93, 'spawn_rate': 93, 'payload_size': 297353, 'csv_filename': 'results_297353_93'} as results already exist.
# Skipping benchmark for task: {'num_users': 154, 'spawn_rate': 154, 'payload_size': 297353, 'csv_filename': 'results_297353_154'} as results already exist.
# Skipping benchmark for task: {'num_users': 256, 'spawn_rate': 256, 'payload_size': 297353, 'csv_filename': 'results_297353_256'} as results already exist.
# Skipping benchmark for task: {'num_users': 1, 'spawn_rate': 1, 'payload_size': 1048576, 'csv_filename': 'results_1048576_1'} as results already exist.
# Skipping benchmark for task: {'num_users': 2, 'spawn_rate': 2, 'payload_size': 1048576, 'csv_filename': 'results_1048576_2'} as results already exist.
# Skipping benchmark for task: {'num_users': 4, 'spawn_rate': 4, 'payload_size': 1048576, 'csv_filename': 'results_1048576_4'} as results already exist.
# Skipping benchmark for task: {'num_users': 7, 'spawn_rate': 7, 'payload_size': 1048576, 'csv_filename': 'results_1048576_7'} as results already exist.
# Skipping benchmark for task: {'num_users': 12, 'spawn_rate': 12, 'payload_size': 1048576, 'csv_filename': 'results_1048576_12'} as results already exist.
# Skipping benchmark for task: {'num_users': 20, 'spawn_rate': 20, 'payload_size': 1048576, 'csv_filename': 'results_1048576_20'} as results already exist.
# Skipping benchmark for task: {'num_users': 34, 'spawn_rate': 34, 'payload_size': 1048576, 'csv_filename': 'results_1048576_34'} as results already exist.
# Skipping benchmark for task: {'num_users': 56, 'spawn_rate': 56, 'payload_size': 1048576, 'csv_filename': 'results_1048576_56'} as results already exist.
# Skipping benchmark for task: {'num_users': 93, 'spawn_rate': 93, 'payload_size': 1048576, 'csv_filename': 'results_1048576_93'} as results already exist.
# Skipping benchmark for task: {'num_users': 154, 'spawn_rate': 154, 'payload_size': 1048576, 'csv_filename': 'results_1048576_154'} as results already exist.
# Skipping benchmark for task: {'num_users': 256, 'spawn_rate': 256, 'payload_size': 1048576, 'csv_filename': 'results_1048576_256'} as results already exist.

# %%
results = []
for task in tasks:
    csv_filename = f".results/{task['csv_filename']}_stats.csv"
    try:
        df = pd.read_csv(csv_filename)
        if not df.empty:
            agg_row = df.iloc[-1]  # Select the last row
            if agg_row["Name"] == "Aggregated":
                results.append({
                    "payload_size": task["payload_size"],
                    "num_users": task["num_users"],
                    "total_requests": int(agg_row["Request Count"]),
                    "avg_response_time": float(agg_row["Average Response Time"]),
                    "med_response_time": float(agg_row["Median Response Time"]),
                })
            else:
                print(f"No aggregated data found in {csv_filename}")
        else:
            print(f"The CSV file is empty: {csv_filename}")
    except FileNotFoundError:
        print(f"Results not found for task: {task}")
    except Exception as e:
        print(f"An error occurred for task {task}: {str(e)}")

results_df = pd.DataFrame(results)
pd.set_option('display.max_rows', None)
print(results_df)
pd.reset_option('display.max_rows')
# Out:
#      payload_size  num_users  total_requests  avg_response_time  \
# 0               1          1            4141           7.154012
# 93          23912         20            9849          60.660850
# 94          23912         34            9251         109.531758
# 95          23912         56            9080         182.859805
# 96          23912         93            9006         301.365942
# 97          23912        154            9011         473.525012
# 98          23912        256            8925         754.841482
# 99          84322          1            3106           9.564154
# 100         84322          2            5288          11.254522
# 101         84322          4            7611          15.660834
# 102         84322          7            8666          24.109591
# 103         84322         12            9060          39.537941
# 104         84322         20            9062          65.930853
# 105         84322         34            8716         116.302229
# 106         84322         56            8506         187.974151
# 107         84322         93            8430         318.731991
# 108         84322        154            8318         504.497491
# 109         84322        256            8203         828.282266
# 110        297353          1            2111          14.062065
# 111        297353          2            3635          16.375364
# 112        297353          4            5321          22.412714
# 113        297353          7            6331          32.985762
# 114        297353         12            6715          53.351002
# 115        297353         20            6854          87.073996
# 116        297353         34            6792         140.661023
# 117        297353         56            6689         249.103593
# 118        297353         93            6342         434.846512
# 119        297353        154            6037         728.198227
# 120        297353        256            5839        1231.028673
# 121       1048576          1            1145          26.039228
# 122       1048576          2            1820          32.792766
# 123       1048576          4            2678          44.608364
# 124       1048576          7            3045          68.692991
# 125       1048576         12            3113         115.148910
# 126       1048576         20            3205         186.356832
# 127       1048576         34            3083         328.424299
# 128       1048576         56            3115         532.666582
# 129       1048576         93            2917         943.877815
# 130       1048576        154            2682        1662.931973
# 131       1048576        256            2425        2768.216179
#
#      med_response_time
# 0                  7.0
# 1                  8.0
# 2                 12.0
# 3                 19.0
# 4                 31.0
# 5                 52.0
# 6                 91.0
# 7                160.0
# 8                260.0
# 9                360.0
# 10               610.0
# 11                 7.0
# 12                 8.0
# 13                12.0
# 14                19.0
# 15                31.0
# 16                52.0
# 17                91.0
# 18               150.0
# 19               250.0
# 20               390.0
# 21               580.0
# 22                 7.0
# 23                 9.0
# 24                12.0
# 25                19.0
# 26                31.0
# 27                52.0
# 28                90.0
# 29               150.0
# 30               240.0
# 31               380.0
# 32               620.0
# 33                 7.0
# 34                 9.0
# 35                12.0
# 36                19.0
# 37                31.0
# 38                52.0
# 39                92.0
# 40               150.0
# 41               250.0
# 42               390.0
# 43               580.0
# 44                 7.0
# 45                 9.0
# 46                12.0
# 47                19.0
# 48                31.0
# 49                51.0
# 50                92.0
# 51               150.0
# 52               240.0
# 53               390.0
# 54               620.0
# 55                 7.0
# 56                 9.0
# 57                12.0
# 58                19.0
# 59                31.0
# 60                52.0
# 61                92.0
# 62               150.0
# 63               240.0
# 64               380.0
# 65               620.0
# 66                 7.0
# 67                 9.0
# 68                12.0
# 69                19.0
# 70                31.0
# 71                52.0
# 72                91.0
# 73               150.0
# 74               250.0
# 75               390.0
# 76               690.0
# 77                 7.0
# 78                 8.0
# 79                12.0
# 80                20.0
# 81                32.0
# 82                53.0
# 83                92.0
# 84               150.0
# 85               240.0
# 86               400.0
# 87               610.0
# 88                 8.0
# 89                10.0
# 90                13.0
# 91                20.0
# 92                33.0
# 93                55.0
# 94                97.0
# 95               160.0
# 96               260.0
# 97               370.0
# 98               650.0
# 99                10.0
# 100               11.0
# 101               15.0
# 102               23.0
# 103               38.0
# 104               61.0
# 105              100.0
# 106              160.0
# 107              270.0
# 108              420.0
# 109              700.0
# 110               14.0
# 111               16.0
# 112               22.0
# 113               32.0
# 114               51.0
# 115               81.0
# 116              130.0
# 117              220.0
# 118              380.0
# 119              620.0
# 120             1000.0
# 121               26.0
# 122               33.0
# 123               43.0
# 124               67.0
# 125              110.0
# 126              180.0
# 127              320.0
# 128              510.0
# 129              890.0
# 130             1600.0
# 131             2500.0

# %%
# Add columns for requests per second and requests per second
from email.mime import base


results_df['requests_per_second'] = results_df['total_requests'] / run_time_seconds / 1000

#results_df['avg_response_time_per_user'] = results_df['avg_response_time'] / results_df['num_users']
results_df['med_response_time_per_user'] = results_df['med_response_time'] / results_df['num_users']
results_df['throughput'] = results_df['total_requests'] / run_time_seconds * results_df['payload_size'] / 1024 / 1024 # MB/s

# Pivot the DataFrames for the heatmaps
heatmap_data_rps = results_df.pivot(index="payload_size", columns="num_users", values="requests_per_second")
heatmap_data_rt = results_df.pivot(index="payload_size", columns="num_users", values="throughput")

# Set up the matplotlib figure
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 8))

# Draw the heatmap for average response time
sns.heatmap(heatmap_data_rps, cmap="viridis", annot=True, fmt=".2f", linewidths=.5, cbar_kws={"label": "1000 Requests per Second"}, ax=axes[0])
axes[0].set_title('1000 Requests per Second')
axes[0].set_xlabel('Number of Users')
axes[0].set_ylabel('Payload Size (Bytes)')

# Draw the heatmap for requests per second per user
log_heatmap_data = np.log2(heatmap_data_rt + 1e-6)
sns.heatmap(log_heatmap_data, cmap="viridis", annot=True, fmt=".2f", linewidths=.5, cbar_kws={"label": "Throughput Log2(MB/s)"}, ax=axes[1])
axes[1].set_title('Throughput')
axes[1].set_xlabel('Number of Users')
axes[1].set_ylabel('Payload Size (Bytes)')

plt.tight_layout()
plt.show()

# %%
print( results_df['num_users'])
# Out:
# 0        1
# 1        2
# 2        4
# 3        7
# 4       12
#       ...
# 127     34
# 128     56
# 129     93
# 130    154
# 131    256
# Name: num_users, Length: 132, dtype: int64

# %%
# Assuming 'results_df' is your DataFrame

# First, we will group the data by 'payload_size' and calculate the mean 'total_requests' and 'avg_response_time'.
# This is necessary because your data seems to have multiple entries for each 'payload_size'.
grouped = results_df.groupby('payload_size').mean().reset_index()
results_df['throughput'] = results_df['total_requests'] / run_time_seconds * results_df['payload_size'] / 1024 / 1024 # MB/s

# Now let's plot the data
fig, ax1 = plt.subplots(figsize=(10, 5))

# Adding gridlines
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# Set the x-axis label
ax1.set_xlabel('Payload Size (bytes)', fontsize=14)

# Plot the 'total_requests' on the left y-axis
ax1.set_ylabel('Total Requests', color='tab:blue', fontsize=14)
ax1.plot(grouped['payload_size'], grouped['total_requests'], color='tab:blue', label='Total Requests')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis to share the same x-axis
ax2 = ax1.twinx()  
ax2.set_ylabel('Throughput (MB/s)', color='tab:red', fontsize=14)  # we already handled the x-label with ax1
ax2.plot(grouped['payload_size'], grouped['throughput'], color='tab:red', label='Throughput')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Set the title of the plot
plt.title('Requests per Second and Throughput by Payload Size', fontsize=16)

# Show a legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>
