# %%
# %pip install numpy pandas seaborn matplotlib
# Out:
# Requirement already satisfied: numpy in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (1.26.1)
# Requirement already satisfied: pandas in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: seaborn in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (0.13.0)
# Requirement already satisfied: matplotlib in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: six>=1.5 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from math import log
import subprocess

num_steps_users = 12  # Number of steps for users
num_steps_sizes = 24  # Number of steps for payload sizes
run_time_seconds = 30  # Number of seconds to run each test
num_workers = 4 # Number of workers to use for each test

num_users_list = np.array([20])
payload_sizes = np.unique(np.logspace(0, 20, num=num_steps_sizes, base=2).astype(int))  # Logarithmically spaced sizes, ensure unique values


# fix user, small files between 1byte and 100kb
#min_size_log2 = 0  # log2(1 byte)
#max_size_log2 = log(100 * 1024, 2)  # log2(100 KB)
#num_steps_sizes = 32  # Number of steps for payload sizes
#payload_sizes = np.unique(np.logspace(min_size_log2, max_size_log2, num=num_steps_sizes, base=2).astype(int))
#num_users_list = np.full(1, 500)

# %%
tasks = []
for payload_size in payload_sizes:
    for num_users in num_users_list:
        task = {
            "num_users": num_users,
            "spawn_rate": num_users,  # Adjust as needed
            "payload_size": payload_size,
            "csv_filename": f"results_{payload_size}_{num_users}"
        }
        tasks.append(task)

# View first 5 tasks as an example
tasks_df = pd.DataFrame(tasks)

pd.set_option('display.max_rows', None)
print(tasks_df)
pd.reset_option('display.max_rows')
# Out:
#     num_users  spawn_rate  payload_size        csv_filename
# 0          20          20             1        results_1_20
# 1          20          20             3        results_3_20
# 2          20          20             6        results_6_20
# 3          20          20            11       results_11_20
# 4          20          20            20       results_20_20
# 5          20          20            37       results_37_20
# 6          20          20            67       results_67_20
# 7          20          20           124      results_124_20
# 8          20          20           226      results_226_20
# 9          20          20           414      results_414_20
# 10         20          20           757      results_757_20
# 11         20          20          1384     results_1384_20
# 12         20          20          2528     results_2528_20
# 13         20          20          4620     results_4620_20
# 14         20          20          8442     results_8442_20
# 15         20          20         15425    results_15425_20
# 16         20          20         28184    results_28184_20
# 17         20          20         51496    results_51496_20
# 18         20          20         94089    results_94089_20
# 19         20          20        171911   results_171911_20
# 20         20          20        314101   results_314101_20
# 21         20          20        573897   results_573897_20
# 22         20          20       1048576  results_1048576_20

# %%
# Set the aesthetics for the plot
sns.set(style="whitegrid")

# Create the scatter plot
plt.figure(figsize=(10, 6))
ax = sns.scatterplot(data=tasks_df, x='payload_size', y='num_users', size='num_users', hue='num_users', palette='viridis', sizes=(20, 200))

# Set the scale of the x/y-axis to logarithmic to better visualize the data
ax.set_xscale('log', base=2)
ax.set_yscale('log', base=2)

# Set plot labels and title
ax.set_xlabel('Payload Size (Bytes)')
ax.set_ylabel('Number of Users')
ax.set_title('Number of Users vs Payload Size for Each Task')

# Show the plot
plt.show()

# %%
def run_benchmark_docker(task):
    results_file_path = f"results/{task['csv_filename']}"

    # Check if the results file already exists
    if os.path.exists(f".{results_file_path}_stats.csv"):
        print(f"Skipping benchmark for task: {task} as results already exist.")
        return
    
    # Set environment variables
    os.environ['NUM_USERS'] = str(task['num_users'])
    os.environ['SPAWN_RATE'] = str(task['spawn_rate'])
    os.environ['RUN_TIME'] = str(run_time_seconds)
    os.environ['CSV_FILENAME'] = results_file_path
    os.environ['PAYLOAD_SIZE'] = str(task['payload_size'])
    os.environ['NUM_WORKERS'] = str(num_workers)
    
    # Run the benchmark using Docker Compose
    subprocess.run(["docker", "compose", "up", "--scale", f"locust-worker={num_workers}"], check=True)

    # Optionally, you can stop and remove containers if needed
    subprocess.run(["docker-compose", "down"], check=True)


# Ensure the results directory exists
os.makedirs('.results', exist_ok=True)

#for task in tasks:
#    run_benchmark_docker(task)

# %%
def run_benchmark_local(task):
    results_file_path = f".results/{task['csv_filename']}"

    # Check if the results file already exists
    if os.path.exists(f"{results_file_path}_stats.csv"):
        print(f"Skipping benchmark for task: {task} as results already exist.")
        return
    
    os.environ['PAYLOAD_SIZE'] = str(task['payload_size'])
    os.environ['NUM_WORKERS'] = str(num_workers)
    
    # Command to start the Locust master
    master_command = ["locust", "-f", "../locust/locustfile.py", "--master", "--headless", 
                      "--expect-workers", "4",
                      "--host", "http://192.168.1.105:8000", 
                      "-u", str(task['num_users']), 
                      "-r", str(task['spawn_rate']), 
                      "--run-time", str(run_time_seconds),
                      "--csv", results_file_path]

    # Commands to start Locust workers
    worker_commands = [
        ["locust", "-f", "../locust/locustfile.py", "--worker", "--master-host", "127.0.0.1"] for _ in range(num_workers)
    ]

    # Start the Locust master
    master_process = subprocess.Popen(master_command)

    # Start the worker processes
    worker_processes = [subprocess.Popen(cmd) for cmd in worker_commands]
    
    try:
        # Wait for the master process to complete
        master_process.wait()
    except KeyboardInterrupt:
        # Handle Ctrl+C
        pass
    finally:
        # Terminate all processes
        master_process.terminate()
        for worker in worker_processes:
            worker.terminate()


# Ensure the results directory exists
os.makedirs('.results', exist_ok=True)

for task in tasks:
    run_benchmark_local(task)
# Out:
# payload_size: 1payload_size: 1payload_size: 1
#
#
# payload_size: 1
# payload_size: 1
# [2023-11-12 23:35:12,259] BUD-MAC-16300-(26473)/INFO/root: Waiting for workers to be ready, 0 of 4 connected
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# [2023-11-12 23:35:12,264] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_2601dd55ec514dc9868e844c80d940de (index 0) reported as ready. 1 workers connected.
# [2023-11-12 23:35:12,264] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_61da506ca30d4e8c8dd83f6f4e5d3742 (index 1) reported as ready. 2 workers connected.
# [2023-11-12 23:35:12,265] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_a2daf9a44406437dbe7ada37efa37fe4 (index 2) reported as ready. 3 workers connected.
# [2023-11-12 23:35:12,265] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_b496d054247a4870b6f19a214d554bc9 (index 3) reported as ready. 4 workers connected.
# [2023-11-12 23:35:12,266] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:35:12,267] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:35:12,267] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:35:12,267] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:35:13,266] BUD-MAC-16300-(26473)/INFO/locust.main: Run time limit set to 30 seconds
# [2023-11-12 23:35:13,266] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:35:13,266] BUD-MAC-16300-(26473)/INFO/locust.runners: Sending spawn jobs of 20 users at 20.00 spawn rate to 4 ready workers
# [2023-11-12 23:35:13,334] BUD-MAC-16300-(26473)/INFO/locust.runners: All users spawned: {"StorageUser": 20} (20 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                389     0(0.00%) |     95      14     298     81 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       389     0(0.00%) |     95      14     298     81 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                540     0(0.00%) |     96      12     308     80 |  141.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       540     0(0.00%) |     96      12     308     80 |  141.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                991     0(0.00%) |     98      12     401     81 |  179.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       991     0(0.00%) |     98      12     401     81 |  179.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1619     0(0.00%) |     97      11     537     79 |  190.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1619     0(0.00%) |     97      11     537     79 |  190.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1619     0(0.00%) |     97      11     537     79 |  190.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1619     0(0.00%) |     97      11     537     79 |  190.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2243     0(0.00%) |     96      11     537     80 |  197.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2243     0(0.00%) |     96      11     537     80 |  197.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2868     0(0.00%) |     96      11     537     79 |  207.20        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2868     0(0.00%) |     96      11     537     79 |  207.20        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3480     0(0.00%) |     95      10     537     78 |  208.80        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3480     0(0.00%) |     95      10     537     78 |  208.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3480     0(0.00%) |     95      10     537     78 |  208.80        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3480     0(0.00%) |     95      10     537     78 |  208.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               4094     0(0.00%) |     95      10     537     79 |  206.20        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      4094     0(0.00%) |     95      10     537     79 |  206.20        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               4717     0(0.00%) |     94      10     537     79 |  205.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      4717     0(0.00%) |     94      10     537     79 |  206.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               4717     0(0.00%) |     94      10     537     79 |  205.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      4717     0(0.00%) |     94      10     537     79 |  206.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               5346     0(0.00%) |     94      10     537     80 |  205.70        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      5346     0(0.00%) |     94      10     537     80 |  205.70        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               5956     0(0.00%) |     94      10     537     80 |  206.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      5956     0(0.00%) |     94      10     537     80 |  206.10        0.00
#
# [2023-11-12 23:35:43,267] BUD-MAC-16300-(26473)/INFO/locust.main: --run-time limit reached, shutting down
# [2023-11-12 23:35:43,268] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:35:43,269] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:35:43,269] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:35:43,269] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:35:43,272] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:35:43,272] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:35:43,272] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:35:43,273] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:35:43,273] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_a2daf9a44406437dbe7ada37efa37fe4' (index 2) quit. 0 workers ready.
# [2023-11-12 23:35:43,273] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_2601dd55ec514dc9868e844c80d940de' (index 0) quit. 0 workers ready.
# [2023-11-12 23:35:43,273] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_b496d054247a4870b6f19a214d554bc9' (index 3) quit. 0 workers ready.
# [2023-11-12 23:35:43,273] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_61da506ca30d4e8c8dd83f6f4e5d3742' (index 1) quit. 0 workers ready.
# [2023-11-12 23:35:43,274] BUD-MAC-16300-(26473)/INFO/locust.runners: The last worker quit, stopping test.
# [2023-11-12 23:35:44,278] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               6158     0(0.00%) |     94      10     537     80 |  205.35        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      6158     0(0.00%) |     94      10     537     80 |  205.35        0.00
#
# Response time percentiles (approximated)
# Type     Name                                                                                  50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
# PUT      /                                                                                      80    100    120    130    170    210    260    300    450    540    540   6158
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated                                                                             80    100    120    130    170    210    260    300    450    540    540   6158
# payload_size: 3payload_size: 3
#
# payload_size: 3
# payload_size: 3
# payload_size: 3
# [2023-11-12 23:35:45,407] BUD-MAC-16300-(26473)/INFO/root: Waiting for workers to be ready, 0 of 4 connected
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# [2023-11-12 23:35:45,411] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_4cc637862a10439282f34b2b07a25516 (index 0) reported as ready. 1 workers connected.
# [2023-11-12 23:35:45,411] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_2af1095a2d4f44f9b2a8589f8f333f05 (index 1) reported as ready. 2 workers connected.
# [2023-11-12 23:35:45,412] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_338a241044c246afa0fb76d71847a34a (index 2) reported as ready. 3 workers connected.
# [2023-11-12 23:35:45,413] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:35:45,413] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:35:45,414] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:35:45,416] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_3398d0575e19459f872d0c0a8f97bd45 (index 3) reported as ready. 4 workers connected.
# [2023-11-12 23:35:45,417] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:35:46,410] BUD-MAC-16300-(26473)/INFO/locust.main: Run time limit set to 30 seconds
# [2023-11-12 23:35:46,410] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:35:46,410] BUD-MAC-16300-(26473)/INFO/locust.runners: Sending spawn jobs of 20 users at 20.00 spawn rate to 4 ready workers
# [2023-11-12 23:35:46,471] BUD-MAC-16300-(26473)/INFO/locust.runners: All users spawned: {"StorageUser": 20} (20 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                371     1(0.27%) |     96      12     434     72 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       371     1(0.27%) |     96      12     434     72 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                371     1(0.27%) |     96      12     434     72 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       371     1(0.27%) |     96      12     434     72 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                985     1(0.10%) |     94      12     438     75 |  161.33        0.33
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       985     1(0.10%) |     94      12     438     75 |  161.33        0.33
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1614     1(0.06%) |     92      10     438     76 |  185.17        0.17
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1614     1(0.06%) |     92      10     438     76 |  185.17        0.17
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1614     1(0.06%) |     92      10     438     76 |  185.17        0.17
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1614     1(0.06%) |     92      10     438     76 |  185.17        0.17
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2242     1(0.04%) |     91      10     438     76 |  193.11        0.11
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2242     1(0.04%) |     91      10     438     76 |  193.11        0.11
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2855     1(0.04%) |     90      10     438     77 |  207.60        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2855     1(0.04%) |     90      10     438     77 |  207.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3468     1(0.03%) |     90      10     438     77 |  207.40        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3468     1(0.03%) |     90      10     438     77 |  207.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3468     1(0.03%) |     90      10     438     77 |  207.40        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3468     1(0.03%) |     90      10     438     77 |  207.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               4084     1(0.02%) |     90      10     438     77 |  205.20        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      4084     1(0.02%) |     90      10     438     77 |  205.20        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               4702     1(0.02%) |     89      10     438     76 |  204.80        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      4702     1(0.02%) |     89      10     438     76 |  204.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               4702     1(0.02%) |     89      10     438     76 |  204.80        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      4702     1(0.02%) |     89      10     438     76 |  204.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               5318     1(0.02%) |     89      10     455     76 |  204.50        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      5318     1(0.02%) |     89      10     455     76 |  204.50        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               5945     1(0.02%) |     88      10     455     75 |  205.70        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      5945     1(0.02%) |     88      10     455     75 |  205.70        0.00
#
# [2023-11-12 23:36:16,413] BUD-MAC-16300-(26473)/INFO/locust.main: --run-time limit reached, shutting down
# [2023-11-12 23:36:16,414] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:36:16,414] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:36:16,414] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:36:16,414] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:36:16,416] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:36:16,416] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:36:16,416] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:36:16,416] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:36:16,416] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_2af1095a2d4f44f9b2a8589f8f333f05' (index 1) quit. 0 workers ready.
# [2023-11-12 23:36:16,417] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_3398d0575e19459f872d0c0a8f97bd45' (index 3) quit. 0 workers ready.
# [2023-11-12 23:36:16,417] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_338a241044c246afa0fb76d71847a34a' (index 2) quit. 0 workers ready.
# [2023-11-12 23:36:16,417] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_4cc637862a10439282f34b2b07a25516' (index 0) quit. 0 workers ready.
# [2023-11-12 23:36:16,417] BUD-MAC-16300-(26473)/INFO/locust.runners: The last worker quit, stopping test.
# [2023-11-12 23:36:17,424] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 1)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               6147     1(0.02%) |     88      10     455     75 |  204.91        0.03
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      6147     1(0.02%) |     88      10     455     75 |  204.91        0.03
#
# Response time percentiles (approximated)
# Type     Name                                                                                  50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
# PUT      /                                                                                      75     95    110    120    160    200    250    290    400    460    460   6147
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated                                                                             75     95    110    120    160    200    250    290    400    460    460   6147
#
# Error report
# # occurrences      Error
# ------------------|---------------------------------------------------------------------------------------------------------------------------------------------
# 1                  PUT /: "HTTPError('500 Server Error: Internal Server Error for url: /')"
# ------------------|---------------------------------------------------------------------------------------------------------------------------------------------
# payload_size: 6
# payload_size: 6
# payload_size: 6
# payload_size: 6
# payload_size: 6
# [2023-11-12 23:36:18,573] BUD-MAC-16300-(26473)/INFO/root: Waiting for workers to be ready, 0 of 4 connected
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# [2023-11-12 23:36:18,576] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_a74079e2566f46e4b253d6d496533423 (index 0) reported as ready. 1 workers connected.
# [2023-11-12 23:36:18,576] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_d54ac763341c412e87b6bd93b1aede7c (index 1) reported as ready. 2 workers connected.
# [2023-11-12 23:36:18,577] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_a8c4c97e28a54d1080420f77e636b14d (index 2) reported as ready. 3 workers connected.
# [2023-11-12 23:36:18,578] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:36:18,578] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:36:18,579] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:36:18,580] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_b5d5ff55b4ba40f1870c4cd962fe5bea (index 3) reported as ready. 4 workers connected.
# [2023-11-12 23:36:18,581] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:36:19,580] BUD-MAC-16300-(26473)/INFO/locust.main: Run time limit set to 30 seconds
# [2023-11-12 23:36:19,580] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:36:19,581] BUD-MAC-16300-(26473)/INFO/locust.runners: Sending spawn jobs of 20 users at 20.00 spawn rate to 4 ready workers
# [2023-11-12 23:36:19,642] BUD-MAC-16300-(26473)/INFO/locust.runners: All users spawned: {"StorageUser": 20} (20 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                363     0(0.00%) |    100      12     373     85 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       363     0(0.00%) |    100      12     373     85 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                363     0(0.00%) |    100      12     373     85 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       363     0(0.00%) |    100      12     373     85 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                979     0(0.00%) |     94      12     380     82 |  150.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       979     0(0.00%) |     94      12     380     82 |  150.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1592     0(0.00%) |     94      11     380     80 |  177.17        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1592     0(0.00%) |     94      11     380     80 |  177.17        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2048     0(0.00%) |     93      11     380     80 |  183.89        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2048     0(0.00%) |     93      11     380     80 |  183.89        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2201     0(0.00%) |     94      11     407     81 |  186.11        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2201     0(0.00%) |     94      11     407     81 |  186.11        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2812     0(0.00%) |     93      11     426     80 |  203.60        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2812     0(0.00%) |     93      11     426     80 |  203.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3278     0(0.00%) |     93      11     426     80 |  200.60        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3278     0(0.00%) |     93      11     426     80 |  200.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3445     0(0.00%) |     93      11     426     81 |  203.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3445     0(0.00%) |     93      11     426     81 |  203.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               4081     0(0.00%) |     92      11     426     80 |  206.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      4081     0(0.00%) |     92      11     426     80 |  206.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               4707     0(0.00%) |     92      11     426     80 |  208.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# ...
# [2023-11-12 23:47:23,645] BUD-MAC-16300-(26473)/INFO/locust.main: Run time limit set to 30 seconds
# [2023-11-12 23:47:23,645] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 23:47:23,646] BUD-MAC-16300-(26473)/INFO/locust.runners: Sending spawn jobs of 20 users at 20.00 spawn rate to 4 ready workers
# [2023-11-12 23:47:23,704] BUD-MAC-16300-(26473)/INFO/locust.runners: All users spawned: {"StorageUser": 20} (20 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                149     0(0.00%) |    244      75     604    240 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       149     0(0.00%) |    244      75     604    240 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                149     0(0.00%) |    244      75     604    240 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       149     0(0.00%) |    244      75     604    240 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                405     0(0.00%) |    238      66     661    220 |   59.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       405     0(0.00%) |    238      66     661    220 |   59.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                656     0(0.00%) |    238      66     661    230 |   72.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       656     0(0.00%) |    238      66     661    230 |   72.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                780     0(0.00%) |    238      66     661    230 |   74.56        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       780     0(0.00%) |    238      66     661    230 |   74.56        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                919     0(0.00%) |    235      66     661    220 |   76.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       919     0(0.00%) |    235      66     661    220 |   76.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1177     0(0.00%) |    234      66     661    220 |   85.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1177     0(0.00%) |    234      66     661    220 |   85.90        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1307     0(0.00%) |    233      61     661    220 |   84.50        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1307     0(0.00%) |    233      61     661    220 |   84.50        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1442     0(0.00%) |    232      56     661    220 |   86.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1442     0(0.00%) |    232      56     661    220 |   86.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1700     0(0.00%) |    233      56     694    220 |   86.70        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1700     0(0.00%) |    233      56     694    220 |   86.70        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1822     0(0.00%) |    233      56     694    220 |   85.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1822     0(0.00%) |    233      56     694    220 |   85.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1955     0(0.00%) |    233      56     694    220 |   86.60        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1955     0(0.00%) |    233      56     694    220 |   86.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2216     0(0.00%) |    233      44     694    220 |   86.20        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2216     0(0.00%) |    233      44     694    220 |   86.20        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2471     0(0.00%) |    233      44     694    220 |   85.70        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2471     0(0.00%) |    233      44     694    220 |   85.70        0.00
#
# [2023-11-12 23:47:53,648] BUD-MAC-16300-(26473)/INFO/locust.main: --run-time limit reached, shutting down
# [2023-11-12 23:47:53,649] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:47:53,649] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:47:53,649] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:47:53,650] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 23:47:53,652] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:47:53,653] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:47:53,653] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:47:53,653] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 23:47:53,653] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_dda5d2219c3848019ca1fc2eb4f113d3' (index 0) quit. 0 workers ready.
# [2023-11-12 23:47:53,653] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_559407ff01cf4c0ea0323015e5e36682' (index 1) quit. 0 workers ready.
# [2023-11-12 23:47:53,654] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_fbfb26c77c884340b605715128066ba9' (index 2) quit. 0 workers ready.
# [2023-11-12 23:47:53,654] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_131246d262b144a69c3162913ae26a20' (index 3) quit. 0 workers ready.
# [2023-11-12 23:47:53,654] BUD-MAC-16300-(26473)/INFO/locust.runners: The last worker quit, stopping test.
# [2023-11-12 23:47:54,658] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2553     0(0.00%) |    233      44     694    220 |   85.28        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2553     0(0.00%) |    233      44     694    220 |   85.28        0.00
#
# Response time percentiles (approximated)
# Type     Name                                                                                  50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
# PUT      /                                                                                     220    260    280    310    360    420    480    530    660    690    690   2553
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated                                                                            220    260    280    310    360    420    480    530    660    690    690   2553

# %%
results = []
for task in tasks:
    csv_filename = f".results/{task['csv_filename']}_stats.csv"
    try:
        df = pd.read_csv(csv_filename)
        if not df.empty:
            agg_row = df.iloc[-1]  # Select the last row
            if agg_row["Name"] == "Aggregated":
                results.append({
                    "payload_size": task["payload_size"],
                    "num_users": task["num_users"],
                    "total_requests": int(agg_row["Request Count"]),
                    "avg_response_time": float(agg_row["Average Response Time"]),
                    "med_response_time": float(agg_row["Median Response Time"]),
                })
            else:
                print(f"No aggregated data found in {csv_filename}")
        else:
            print(f"The CSV file is empty: {csv_filename}")
    except FileNotFoundError:
        print(f"Results not found for task: {task}")
    except Exception as e:
        print(f"An error occurred for task {task}: {str(e)}")

results_df = pd.DataFrame(results)
pd.set_option('display.max_rows', None)
print(results_df)
pd.reset_option('display.max_rows')
# Out:
#     payload_size  num_users  total_requests  avg_response_time  \
# 0              1         20            6158          94.183079
# 1              3         20            6147          88.106355
# 2              6         20            6164          92.136772
# 3             11         20            6119          89.426741
# 4             20         20            6108          96.296184
# 5             37         20            6059          83.505396
# 6             67         20            6069          98.303394
# 7            124         20            6097          92.982730
# 8            226         20            6045          98.669218
# 9            414         20            6032          98.105301
# 10           757         20            6008          96.790441
# 11          1384         20            6132          97.403932
# 12          2528         20            5962          97.235908
# 13          4620         20            5930          97.906752
# 14          8442         20            5819         101.150373
# 15         15425         20            5706         102.005165
# 16         28184         20            5670         100.285311
# 17         51496         20            5482         106.975395
# 18         94089         20            5229         101.455980
# 19        171911         20            4771         125.020677
# 20        314101         20            4104         145.227666
# 21        573897         20            3354         177.991018
# 22       1048576         20            2553         233.254443
#
#     med_response_time
# 0                80.0
# 1                75.0
# 2                80.0
# 3                77.0
# 4                81.0
# 5                69.0
# 6                82.0
# 7                79.0
# 8                83.0
# 9                80.0
# 10               82.0
# 11               84.0
# 12               80.0
# 13               80.0
# 14               80.0
# 15               83.0
# 16               83.0
# 17               90.0
# 18               88.0
# 19              110.0
# 20              130.0
# 21              150.0
# 22              220.0

# %%
# Add columns for requests per second and requests per second
results_df['requests_per_second'] = results_df['total_requests'] / run_time_seconds / 1000

#results_df['avg_response_time_per_user'] = results_df['avg_response_time'] / results_df['num_users']
results_df['med_response_time_per_user'] = results_df['med_response_time'] / results_df['num_users']
results_df['throughput'] = results_df['total_requests'] / run_time_seconds * results_df['payload_size'] / 1024 / 1024 # MB/s

# Pivot the DataFrames for the heatmaps
heatmap_data_rps = results_df.pivot(index="payload_size", columns="num_users", values="requests_per_second")
heatmap_data_rt = results_df.pivot(index="payload_size", columns="num_users", values="throughput")

# Set up the matplotlib figure
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 8))

# Draw the heatmap for average response time
sns.heatmap(heatmap_data_rps, cmap="viridis", annot=True, fmt=".2f", linewidths=.5, cbar_kws={"label": "1000 Requests per Second"}, ax=axes[0])
axes[0].set_title('1000 Requests per Second')
axes[0].set_xlabel('Number of Users')
axes[0].set_ylabel('Payload Size (Bytes)')

# Draw the heatmap for requests per second per user
log_heatmap_data = np.log2(heatmap_data_rt + 1e-6)
sns.heatmap(log_heatmap_data, cmap="viridis", annot=True, fmt=".2f", linewidths=.5, cbar_kws={"label": "Throughput Log2(MB/s)"}, ax=axes[1])
axes[1].set_title('Throughput')
axes[1].set_xlabel('Number of Users')
axes[1].set_ylabel('Payload Size (Bytes)')

plt.tight_layout()
plt.show()

# %%
print( results_df['num_users'])
# Out:
# 0     20
# 1     20
# 2     20
# 3     20
# 4     20
# 5     20
# 6     20
# 7     20
# 8     20
# 9     20
# 10    20
# 11    20
# 12    20
# 13    20
# 14    20
# 15    20
# 16    20
# 17    20
# 18    20
# 19    20
# 20    20
# 21    20
# 22    20
# Name: num_users, dtype: int64

# %%
# Assuming 'results_df' is your DataFrame

# First, we will group the data by 'payload_size' and calculate the mean 'total_requests' and 'avg_response_time'.
# This is necessary because your data seems to have multiple entries for each 'payload_size'.
grouped = results_df.groupby('payload_size').mean().reset_index()

# Now let's plot the data
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set the x-axis label
ax1.set_xlabel('Payload Size (bytes)', fontsize=14)

# Plot the 'total_requests' on the left y-axis
ax1.set_ylabel('Total Requests', color='tab:blue', fontsize=14)
ax1.plot(grouped['payload_size'], grouped['total_requests'], color='tab:blue', label='Total Requests')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis to share the same x-axis
ax2 = ax1.twinx()  
ax2.set_ylabel('Average Response Time (ms)', color='tab:red', fontsize=14)  # we already handled the x-label with ax1
ax2.plot(grouped['payload_size'], grouped['avg_response_time'], color='tab:red', label='Average Response Time')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Set the title of the plot
plt.title('Total Requests and Average Response Time by Payload Size', fontsize=16)

# Show a legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.show()
