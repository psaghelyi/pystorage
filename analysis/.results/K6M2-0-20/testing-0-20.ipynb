# %%
# %pip install numpy pandas seaborn matplotlib
# Out:
# Requirement already satisfied: numpy in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (1.26.1)
# Requirement already satisfied: pandas in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: seaborn in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (0.13.0)
# Requirement already satisfied: matplotlib in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: six>=1.5 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from math import log
import subprocess

num_steps_users = 12  # Number of steps for users
num_steps_sizes = 24  # Number of steps for payload sizes
run_time_seconds = 30  # Number of seconds to run each test
num_workers = 4 # Number of workers to use for each test

num_users_list = np.array([20])
payload_sizes = np.unique(np.logspace(0, 20, num=num_steps_sizes, base=2).astype(int))  # Logarithmically spaced sizes, ensure unique values


# fix user, small files between 1byte and 100kb
#min_size_log2 = 0  # log2(1 byte)
#max_size_log2 = log(100 * 1024, 2)  # log2(100 KB)
#num_steps_sizes = 32  # Number of steps for payload sizes
#payload_sizes = np.unique(np.logspace(min_size_log2, max_size_log2, num=num_steps_sizes, base=2).astype(int))
#num_users_list = np.full(1, 500)

# %%
tasks = []
for payload_size in payload_sizes:
    for num_users in num_users_list:
        task = {
            "num_users": num_users,
            "spawn_rate": num_users,  # Adjust as needed
            "payload_size": payload_size,
            "csv_filename": f"results_{payload_size}_{num_users}"
        }
        tasks.append(task)

# View first 5 tasks as an example
tasks_df = pd.DataFrame(tasks)

pd.set_option('display.max_rows', None)
print(tasks_df)
pd.reset_option('display.max_rows')
# Out:
#     num_users  spawn_rate  payload_size        csv_filename
# 0          20          20             1        results_1_20
# 1          20          20             3        results_3_20
# 2          20          20             6        results_6_20
# 3          20          20            11       results_11_20
# 4          20          20            20       results_20_20
# 5          20          20            37       results_37_20
# 6          20          20            67       results_67_20
# 7          20          20           124      results_124_20
# 8          20          20           226      results_226_20
# 9          20          20           414      results_414_20
# 10         20          20           757      results_757_20
# 11         20          20          1384     results_1384_20
# 12         20          20          2528     results_2528_20
# 13         20          20          4620     results_4620_20
# 14         20          20          8442     results_8442_20
# 15         20          20         15425    results_15425_20
# 16         20          20         28184    results_28184_20
# 17         20          20         51496    results_51496_20
# 18         20          20         94089    results_94089_20
# 19         20          20        171911   results_171911_20
# 20         20          20        314101   results_314101_20
# 21         20          20        573897   results_573897_20
# 22         20          20       1048576  results_1048576_20

# %%
# Set the aesthetics for the plot
sns.set(style="whitegrid")

# Create the scatter plot
plt.figure(figsize=(10, 6))
ax = sns.scatterplot(data=tasks_df, x='payload_size', y='num_users', size='num_users', hue='num_users', palette='viridis', sizes=(20, 200))

# Set the scale of the x/y-axis to logarithmic to better visualize the data
ax.set_xscale('log', base=2)
ax.set_yscale('log', base=2)

# Set plot labels and title
ax.set_xlabel('Payload Size (Bytes)')
ax.set_ylabel('Number of Users')
ax.set_title('Number of Users vs Payload Size for Each Task')

# Show the plot
plt.show()

# %%
def run_benchmark_docker(task):
    results_file_path = f"results/{task['csv_filename']}"

    # Check if the results file already exists
    if os.path.exists(f".{results_file_path}_stats.csv"):
        print(f"Skipping benchmark for task: {task} as results already exist.")
        return
    
    # Set environment variables
    os.environ['NUM_USERS'] = str(task['num_users'])
    os.environ['SPAWN_RATE'] = str(task['spawn_rate'])
    os.environ['RUN_TIME'] = str(run_time_seconds)
    os.environ['CSV_FILENAME'] = results_file_path
    os.environ['PAYLOAD_SIZE'] = str(task['payload_size'])
    os.environ['NUM_WORKERS'] = str(num_workers)
    
    # Run the benchmark using Docker Compose
    subprocess.run(["docker", "compose", "up", "--scale", f"locust-worker={num_workers}"], check=True)

    # Optionally, you can stop and remove containers if needed
    subprocess.run(["docker-compose", "down"], check=True)


# Ensure the results directory exists
os.makedirs('.results', exist_ok=True)

#for task in tasks:
#    run_benchmark_docker(task)

# %%
def run_benchmark_local(task):
    results_file_path = f".results/{task['csv_filename']}"

    # Check if the results file already exists
    if os.path.exists(f"{results_file_path}_stats.csv"):
        print(f"Skipping benchmark for task: {task} as results already exist.")
        return
    
    os.environ['PAYLOAD_SIZE'] = str(task['payload_size'])
    os.environ['NUM_WORKERS'] = str(num_workers)
    
    # Command to start the Locust master
    master_command = ["locust", "-f", "../locust/locustfile.py", "--master", "--headless", 
                      "--expect-workers", "4",
                      "--host", "http://192.168.1.105:8000", 
                      "-u", str(task['num_users']), 
                      "-r", str(task['spawn_rate']), 
                      "--run-time", str(run_time_seconds),
                      "--csv", results_file_path]

    # Commands to start Locust workers
    worker_commands = [
        ["locust", "-f", "../locust/locustfile.py", "--worker", "--master-host", "127.0.0.1"] for _ in range(num_workers)
    ]

    # Start the Locust master
    master_process = subprocess.Popen(master_command)

    # Start the worker processes
    worker_processes = [subprocess.Popen(cmd) for cmd in worker_commands]
    
    try:
        # Wait for the master process to complete
        master_process.wait()
    except KeyboardInterrupt:
        # Handle Ctrl+C
        pass
    finally:
        # Terminate all processes
        master_process.terminate()
        for worker in worker_processes:
            worker.terminate()


# Ensure the results directory exists
os.makedirs('.results', exist_ok=True)

for task in tasks:
    run_benchmark_local(task)
# Out:
# payload_size: 1
# payload_size: 1
# payload_size: 1
# payload_size: 1
# payload_size: 1
# [2023-11-12 22:00:44,034] BUD-MAC-16300-(26473)/INFO/root: Waiting for workers to be ready, 0 of 4 connected
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# [2023-11-12 22:00:44,052] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_fcd0e3377c404cb480616d24a2f80953 (index 0) reported as ready. 1 workers connected.
# [2023-11-12 22:00:44,054] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:00:44,056] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_9e540dfac8fd40839e0acae697df6271 (index 1) reported as ready. 2 workers connected.
# [2023-11-12 22:00:44,058] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_38d1dc20e1154a649dd51d56672d895a (index 2) reported as ready. 3 workers connected.
# [2023-11-12 22:00:44,058] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:00:44,059] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_62b64fdc9f2f40b9aa11f175da623827 (index 3) reported as ready. 4 workers connected.
# [2023-11-12 22:00:44,060] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:00:44,060] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:00:45,037] BUD-MAC-16300-(26473)/INFO/locust.main: Run time limit set to 30 seconds
# [2023-11-12 22:00:45,037] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:00:45,038] BUD-MAC-16300-(26473)/INFO/locust.runners: Sending spawn jobs of 20 users at 20.00 spawn rate to 4 ready workers
# [2023-11-12 22:00:45,113] BUD-MAC-16300-(26473)/INFO/locust.runners: All users spawned: {"StorageUser": 20} (20 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                662     0(0.00%) |     58      11     174     53 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       662     0(0.00%) |     58      11     174     53 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                662     0(0.00%) |     58      11     174     53 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       662     0(0.00%) |     58      11     174     53 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1744     0(0.00%) |     56      11     174     52 |  335.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1744     0(0.00%) |     56      11     174     52 |  335.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2832     0(0.00%) |     55      11     181     51 |  346.67        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2832     0(0.00%) |     55      11     181     51 |  346.67        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2832     0(0.00%) |     55      11     181     51 |  346.67        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2832     0(0.00%) |     55      11     181     51 |  346.67        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3937     0(0.00%) |     55      10     181     50 |  354.56        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3937     0(0.00%) |     55      10     181     50 |  354.56        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               5023     0(0.00%) |     55      10     184     50 |  364.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      5023     0(0.00%) |     55      10     184     50 |  364.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               5284     0(0.00%) |     55      10     184     51 |  337.40        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      5284     0(0.00%) |     55      10     184     51 |  337.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               6105     0(0.00%) |     55      10     184     50 |  362.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      6105     0(0.00%) |     55      10     184     50 |  362.90        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               7194     0(0.00%) |     55      10     184     51 |  363.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      7194     0(0.00%) |     55      10     184     51 |  363.10        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               8314     0(0.00%) |     55      10     184     50 |  363.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      8314     0(0.00%) |     55      10     184     50 |  363.90        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               8314     0(0.00%) |     55      10     184     50 |  363.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      8314     0(0.00%) |     55      10     184     50 |  363.90        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               9382     0(0.00%) |     55      10     186     50 |  364.70        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      9382     0(0.00%) |     55      10     186     50 |  364.70        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              10487     0(0.00%) |     55      10     208     50 |  364.70        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     10487     0(0.00%) |     55      10     208     50 |  364.70        0.00
#
# [2023-11-12 22:01:15,041] BUD-MAC-16300-(26473)/INFO/locust.main: --run-time limit reached, shutting down
# [2023-11-12 22:01:15,041] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:01:15,041] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:01:15,041] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:01:15,041] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:01:15,043] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:01:15,044] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:01:15,044] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_fcd0e3377c404cb480616d24a2f80953' (index 0) quit. 0 workers ready.
# [2023-11-12 22:01:15,044] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:01:15,044] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_38d1dc20e1154a649dd51d56672d895a' (index 2) quit. 0 workers ready.
# [2023-11-12 22:01:15,044] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:01:15,045] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_9e540dfac8fd40839e0acae697df6271' (index 1) quit. 0 workers ready.
# [2023-11-12 22:01:15,045] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_62b64fdc9f2f40b9aa11f175da623827' (index 3) quit. 0 workers ready.
# [2023-11-12 22:01:15,045] BUD-MAC-16300-(26473)/INFO/locust.runners: The last worker quit, stopping test.
# [2023-11-12 22:01:16,049] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              10851     0(0.00%) |     55      10     208     50 |  361.73        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     10851     0(0.00%) |     55      10     208     50 |  361.73        0.00
#
# Response time percentiles (approximated)
# Type     Name                                                                                  50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
# PUT      /                                                                                      50     60     67     72     86    100    120    130    170    210    210  10851
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated                                                                             50     60     67     72     86    100    120    130    170    210    210  10851
# payload_size: 3
# payload_size: 3
# payload_size: 3
# payload_size: 3
# payload_size: 3
# [2023-11-12 22:01:17,194] BUD-MAC-16300-(26473)/INFO/root: Waiting for workers to be ready, 0 of 4 connected
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# [2023-11-12 22:01:17,197] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_49d1c3b2ef3344ec87bff3a6ff1109d8 (index 0) reported as ready. 1 workers connected.
# [2023-11-12 22:01:17,198] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_cbe8e2dae05444fc8e46771ede6ee4d2 (index 1) reported as ready. 2 workers connected.
# [2023-11-12 22:01:17,199] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:01:17,199] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:01:17,206] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_f937f59988ec41d68cd86c150d8353ea (index 2) reported as ready. 3 workers connected.
# [2023-11-12 22:01:17,207] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:01:17,211] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_b93b4e393c484a45bbe6b41304e2fa5c (index 3) reported as ready. 4 workers connected.
# [2023-11-12 22:01:17,212] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:01:18,197] BUD-MAC-16300-(26473)/INFO/locust.main: Run time limit set to 30 seconds
# [2023-11-12 22:01:18,197] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:01:18,197] BUD-MAC-16300-(26473)/INFO/locust.runners: Sending spawn jobs of 20 users at 20.00 spawn rate to 4 ready workers
# [2023-11-12 22:01:18,266] BUD-MAC-16300-(26473)/INFO/locust.runners: All users spawned: {"StorageUser": 20} (20 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                679     0(0.00%) |     56      14     201     52 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       679     0(0.00%) |     56      14     201     52 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1221     0(0.00%) |     55      12     201     51 |  272.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1221     0(0.00%) |     55      12     201     51 |  272.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1762     0(0.00%) |     55      12     201     51 |  319.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1762     0(0.00%) |     55      12     201     51 |  319.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2876     0(0.00%) |     54      11     201     50 |  342.83        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2876     0(0.00%) |     54      11     201     50 |  342.83        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3407     0(0.00%) |     55      11     201     51 |  335.56        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3407     0(0.00%) |     55      11     201     51 |  335.56        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3961     0(0.00%) |     55      11     201     51 |  351.78        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3961     0(0.00%) |     55      11     201     51 |  351.78        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               5045     0(0.00%) |     55      11     201     50 |  366.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      5045     0(0.00%) |     55      11     201     50 |  366.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               6143     0(0.00%) |     55      11     201     51 |  363.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      6143     0(0.00%) |     55      11     201     51 |  363.90        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               6143     0(0.00%) |     55      11     201     51 |  363.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      6143     0(0.00%) |     55      11     201     51 |  363.90        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               7237     0(0.00%) |     54       7     201     50 |  362.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      7237     0(0.00%) |     54       7     201     50 |  362.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               8321     0(0.00%) |     55       7     201     50 |  365.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      8321     0(0.00%) |     55       7     201     50 |  365.10        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               8321     0(0.00%) |     55       7     201     50 |  365.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      8321     0(0.00%) |     55       7     201     50 |  365.10        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               9432     0(0.00%) |     54       7     203     50 |  366.50        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      9432     0(0.00%) |     54       7     203     50 |  366.50        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              10514     0(0.00%) |     54       7     203     50 |  365.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     10514     0(0.00%) |     54       7     203     50 |  365.30        0.00
#
# [2023-11-12 22:01:48,199] BUD-MAC-16300-(26473)/INFO/locust.main: --run-time limit reached, shutting down
# [2023-11-12 22:01:48,200] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:01:48,200] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:01:48,200] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:01:48,200] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:01:48,203] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:01:48,203] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:01:48,203] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:01:48,203] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:01:48,203] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_b93b4e393c484a45bbe6b41304e2fa5c' (index 3) quit. 0 workers ready.
# [2023-11-12 22:01:48,203] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_cbe8e2dae05444fc8e46771ede6ee4d2' (index 1) quit. 0 workers ready.
# [2023-11-12 22:01:48,203] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_f937f59988ec41d68cd86c150d8353ea' (index 2) quit. 0 workers ready.
# [2023-11-12 22:01:48,204] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_49d1c3b2ef3344ec87bff3a6ff1109d8' (index 0) quit. 0 workers ready.
# [2023-11-12 22:01:48,204] BUD-MAC-16300-(26473)/INFO/locust.runners: The last worker quit, stopping test.
# [2023-11-12 22:01:49,205] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              10865     0(0.00%) |     54       7     203     50 |  362.21        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     10865     0(0.00%) |     54       7     203     50 |  362.21        0.00
#
# Response time percentiles (approximated)
# Type     Name                                                                                  50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
# PUT      /                                                                                      50     60     68     72     86    100    120    130    180    200    200  10865
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated                                                                             50     60     68     72     86    100    120    130    180    200    200  10865
# payload_size: 6
# payload_size: 6
# payload_size: 6
# payload_size: 6
# payload_size: 6
# [2023-11-12 22:01:50,353] BUD-MAC-16300-(26473)/INFO/root: Waiting for workers to be ready, 0 of 4 connected
# [2023-11-12 22:01:50,355] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_f755bbb2f36c4dc3af11e503e75bd743 (index 0) reported as ready. 1 workers connected.
# [2023-11-12 22:01:50,355] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_df2fc594c63e4bc99eb78d181b853648 (index 1) reported as ready. 2 workers connected.
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# [2023-11-12 22:01:50,356] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:01:50,357] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:01:50,358] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_8859b8412f3945448859d566d04de9de (index 2) reported as ready. 3 workers connected.
# [2023-11-12 22:01:50,360] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:01:50,363] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_41a75d5f214d492fad568fecc4bb1d6c (index 3) reported as ready. 4 workers connected.
# [2023-11-12 22:01:50,365] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:01:51,355] BUD-MAC-16300-(26473)/INFO/locust.main: Run time limit set to 30 seconds
# [2023-11-12 22:01:51,356] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:01:51,356] BUD-MAC-16300-(26473)/INFO/locust.runners: Sending spawn jobs of 20 users at 20.00 spawn rate to 4 ready workers
# [2023-11-12 22:01:51,427] BUD-MAC-16300-(26473)/INFO/locust.runners: All users spawned: {"StorageUser": 20} (20 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                676     0(0.00%) |     56      15     144     51 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       676     0(0.00%) |     56      15     144     51 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1230     0(0.00%) |     55      12     184     50 |  265.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1230     0(0.00%) |     55      12     184     50 |  265.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1775     0(0.00%) |     55      12     191     50 |  303.67        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1775     0(0.00%) |     55      12     191     50 |  303.67        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2868     0(0.00%) |     55      12     191     50 |  335.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2868     0(0.00%) |     55      12     191     50 |  335.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2868     0(0.00%) |     55      12     191     50 |  335.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2868     0(0.00%) |     55      12     191     50 |  335.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3946     0(0.00%) |     55       9     191     50 |  344.78        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3946     0(0.00%) |     55       9     191     50 |  344.78        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               5037     0(0.00%) |     55       9     215     50 |  362.80        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      5037     0(0.00%) |     55       9     215     50 |  362.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               5841     0(0.00%) |     55       9     215     50 |  356.20        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      5841     0(0.00%) |     55       9     215     50 |  356.20        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               6115     0(0.00%) |     55       9     215     50 |  361.50        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      6115     0(0.00%) |     55       9     215     50 |  361.50        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               7207     0(0.00%) |     55       9     215     50 |  361.60        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      7207     0(0.00%) |     55       9     215     50 |  361.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               7748     0(0.00%) |     55       9     215     50 |  350.70        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      7748     0(0.00%) |     55       9     215     50 |  350.70        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# ...
# [2023-11-12 22:12:55,196] BUD-MAC-16300-(26473)/INFO/locust.main: Run time limit set to 30 seconds
# [2023-11-12 22:12:55,196] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 22:12:55,197] BUD-MAC-16300-(26473)/INFO/locust.runners: Sending spawn jobs of 20 users at 20.00 spawn rate to 4 ready workers
# [2023-11-12 22:12:55,262] BUD-MAC-16300-(26473)/INFO/locust.runners: All users spawned: {"StorageUser": 20} (20 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                189     0(0.00%) |    194      64     431    180 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       189     0(0.00%) |    194      64     431    180 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                350     0(0.00%) |    191      64     431    180 |   76.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       350     0(0.00%) |    191      64     431    180 |   76.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                519     0(0.00%) |    188      64     431    180 |   90.67        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       519     0(0.00%) |    188      64     431    180 |   90.67        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                840     0(0.00%) |    187      64     432    180 |   99.50        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       840     0(0.00%) |    187      64     432    180 |   99.50        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1161     0(0.00%) |    186      64     432    180 |  102.44        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1161     0(0.00%) |    186      64     432    180 |  102.44        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1161     0(0.00%) |    186      64     432    180 |  102.44        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1161     0(0.00%) |    186      64     432    180 |  102.44        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1485     0(0.00%) |    186      54     432    180 |  109.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1485     0(0.00%) |    186      54     432    180 |  109.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1809     0(0.00%) |    186      54     432    180 |  107.60        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1809     0(0.00%) |    186      54     432    180 |  107.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1809     0(0.00%) |    186      54     432    180 |  107.60        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1809     0(0.00%) |    186      54     432    180 |  107.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2135     0(0.00%) |    185      45     432    180 |  108.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2135     0(0.00%) |    185      45     432    180 |  108.90        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2459     0(0.00%) |    185      45     432    180 |  106.80        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2459     0(0.00%) |    185      45     432    180 |  106.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2459     0(0.00%) |    185      45     432    180 |  106.80        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2459     0(0.00%) |    185      45     432    180 |  106.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2790     0(0.00%) |    185      45     432    180 |  108.20        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2790     0(0.00%) |    185      45     432    180 |  108.20        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3121     0(0.00%) |    184      45     432    180 |  108.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3121     0(0.00%) |    184      45     432    180 |  108.90        0.00
#
# [2023-11-12 22:13:25,204] BUD-MAC-16300-(26473)/INFO/locust.main: --run-time limit reached, shutting down
# [2023-11-12 22:13:25,204] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:13:25,204] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:13:25,204] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:13:25,205] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 22:13:25,206] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:13:25,206] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:13:25,207] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_ea76637d169d428a8e02694478cc9363' (index 0) quit. 0 workers ready.
# [2023-11-12 22:13:25,207] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_1f36fed3af1b42f394c33ec925d64c4f' (index 2) quit. 0 workers ready.
# [2023-11-12 22:13:25,207] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:13:25,207] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 22:13:25,207] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_50100ae0321b49c58578876d0e8020bd' (index 1) quit. 0 workers ready.
# [2023-11-12 22:13:25,208] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_066ef47a2a284ca984d63aa0b1200171' (index 3) quit. 0 workers ready.
# [2023-11-12 22:13:25,208] BUD-MAC-16300-(26473)/INFO/locust.runners: The last worker quit, stopping test.
# [2023-11-12 22:13:26,223] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3232     0(0.00%) |    184      45     432    180 |  107.74        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3232     0(0.00%) |    184      45     432    180 |  107.74        0.00
#
# Response time percentiles (approximated)
# Type     Name                                                                                  50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
# PUT      /                                                                                     180    200    210    220    250    270    300    320    410    430    430   3232
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated                                                                            180    200    210    220    250    270    300    320    410    430    430   3232

# %%
results = []
for task in tasks:
    csv_filename = f".results/{task['csv_filename']}_stats.csv"
    try:
        df = pd.read_csv(csv_filename)
        if not df.empty:
            agg_row = df.iloc[-1]  # Select the last row
            if agg_row["Name"] == "Aggregated":
                results.append({
                    "payload_size": task["payload_size"],
                    "num_users": task["num_users"],
                    "total_requests": int(agg_row["Request Count"]),
                    "avg_response_time": float(agg_row["Average Response Time"]),
                    "med_response_time": float(agg_row["Median Response Time"]),
                })
            else:
                print(f"No aggregated data found in {csv_filename}")
        else:
            print(f"The CSV file is empty: {csv_filename}")
    except FileNotFoundError:
        print(f"Results not found for task: {task}")
    except Exception as e:
        print(f"An error occurred for task {task}: {str(e)}")

results_df = pd.DataFrame(results)
pd.set_option('display.max_rows', None)
print(results_df)
pd.reset_option('display.max_rows')
# Out:
#     payload_size  num_users  total_requests  avg_response_time  \
# 0              1         20           10851          55.028694
# 1              3         20           10865          54.985683
# 2              6         20           10790          55.372848
# 3             11         20           10859          55.003112
# 4             20         20           10902          54.781716
# 5             37         20           10864          54.986677
# 6             67         20           10806          55.275633
# 7            124         20           10855          55.042107
# 8            226         20           10865          54.977168
# 9            414         20           10819          55.220976
# 10           757         20           10746          55.609697
# 11          1384         20           10751          55.581161
# 12          2528         20           10681          55.932384
# 13          4620         20           10657          56.076674
# 14          8442         20           10528          56.739037
# 15         15425         20           10265          55.412563
# 16         28184         20            9995          59.709822
# 17         51496         20            9749          61.267376
# 18         94089         20            9176          65.102671
# 19        171911         20            8298          72.039042
# 20        314101         20            6880          86.832110
# 21        573897         20            4995         119.511281
# 22       1048576         20            3232         184.774946
#
#     med_response_time
# 0                50.0
# 1                50.0
# 2                50.0
# 3                51.0
# 4                50.0
# 5                50.0
# 6                51.0
# 7                51.0
# 8                50.0
# 9                51.0
# 10               51.0
# 11               52.0
# 12               51.0
# 13               51.0
# 14               52.0
# 15               50.0
# 16               54.0
# 17               57.0
# 18               61.0
# 19               68.0
# 20               83.0
# 21              110.0
# 22              180.0

# %%
# Add columns for requests per second and requests per second
results_df['requests_per_second'] = results_df['total_requests'] / run_time_seconds / 1000

#results_df['avg_response_time_per_user'] = results_df['avg_response_time'] / results_df['num_users']
results_df['med_response_time_per_user'] = results_df['med_response_time'] / results_df['num_users']
results_df['throughput'] = results_df['total_requests'] / run_time_seconds * results_df['payload_size'] / 1024 / 1024 # MB/s

# Pivot the DataFrames for the heatmaps
heatmap_data_rps = results_df.pivot(index="payload_size", columns="num_users", values="requests_per_second")
heatmap_data_rt = results_df.pivot(index="payload_size", columns="num_users", values="throughput")

# Set up the matplotlib figure
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 8))

# Draw the heatmap for average response time
sns.heatmap(heatmap_data_rps, cmap="viridis", annot=True, fmt=".2f", linewidths=.5, cbar_kws={"label": "1000 Requests per Second"}, ax=axes[0])
axes[0].set_title('1000 Requests per Second')
axes[0].set_xlabel('Number of Users')
axes[0].set_ylabel('Payload Size (Bytes)')

# Draw the heatmap for requests per second per user
log_heatmap_data = np.log2(heatmap_data_rt + 1e-6)
sns.heatmap(log_heatmap_data, cmap="viridis", annot=True, fmt=".2f", linewidths=.5, cbar_kws={"label": "Throughput Log2(MB/s)"}, ax=axes[1])
axes[1].set_title('Throughput')
axes[1].set_xlabel('Number of Users')
axes[1].set_ylabel('Payload Size (Bytes)')

plt.tight_layout()
plt.show()

# %%
print( results_df['num_users'])
# Out:
# 0     20
# 1     20
# 2     20
# 3     20
# 4     20
# 5     20
# 6     20
# 7     20
# 8     20
# 9     20
# 10    20
# 11    20
# 12    20
# 13    20
# 14    20
# 15    20
# 16    20
# 17    20
# 18    20
# 19    20
# 20    20
# 21    20
# 22    20
# Name: num_users, dtype: int64

# %%
# Assuming 'results_df' is your DataFrame

# First, we will group the data by 'payload_size' and calculate the mean 'total_requests' and 'avg_response_time'.
# This is necessary because your data seems to have multiple entries for each 'payload_size'.
grouped = results_df.groupby('payload_size').mean().reset_index()

# Now let's plot the data
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set the x-axis label
ax1.set_xlabel('Payload Size (bytes)', fontsize=14)

# Plot the 'total_requests' on the left y-axis
ax1.set_ylabel('Total Requests', color='tab:blue', fontsize=14)
ax1.plot(grouped['payload_size'], grouped['total_requests'], color='tab:blue', label='Total Requests')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis to share the same x-axis
ax2 = ax1.twinx()  
ax2.set_ylabel('Average Response Time (ms)', color='tab:red', fontsize=14)  # we already handled the x-label with ax1
ax2.plot(grouped['payload_size'], grouped['avg_response_time'], color='tab:red', label='Average Response Time')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Set the title of the plot
plt.title('Total Requests and Average Response Time by Payload Size', fontsize=16)

# Show a legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.show()
