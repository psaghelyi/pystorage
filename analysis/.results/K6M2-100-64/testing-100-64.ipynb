# %%
# %pip install numpy pandas seaborn matplotlib
# Out:
# Requirement already satisfied: numpy in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (1.26.1)
# Requirement already satisfied: pandas in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: seaborn in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (0.13.0)
# Requirement already satisfied: matplotlib in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: six>=1.5 in /Users/psaghelyi-remote/.pyenv/versions/pystorage/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from math import log
import subprocess

num_steps_users = 12  # Number of steps for users
num_steps_sizes = 24  # Number of steps for payload sizes
run_time_seconds = 30  # Number of seconds to run each test
num_workers = 4 # Number of workers to use for each test

num_users_list = np.array([64])
payload_sizes = np.unique(np.logspace(0, 20, num=num_steps_sizes, base=2).astype(int))  # Logarithmically spaced sizes, ensure unique values


# fix user, small files between 1byte and 100kb
#min_size_log2 = 0  # log2(1 byte)
#max_size_log2 = log(100 * 1024, 2)  # log2(100 KB)
#num_steps_sizes = 32  # Number of steps for payload sizes
#payload_sizes = np.unique(np.logspace(min_size_log2, max_size_log2, num=num_steps_sizes, base=2).astype(int))
#num_users_list = np.full(1, 500)

# %%
tasks = []
for payload_size in payload_sizes:
    for num_users in num_users_list:
        task = {
            "num_users": num_users,
            "spawn_rate": num_users,  # Adjust as needed
            "payload_size": payload_size,
            "csv_filename": f"results_{payload_size}_{num_users}"
        }
        tasks.append(task)

# View first 5 tasks as an example
tasks_df = pd.DataFrame(tasks)

pd.set_option('display.max_rows', None)
print(tasks_df)
pd.reset_option('display.max_rows')
# Out:
#     num_users  spawn_rate  payload_size        csv_filename
# 0          64          64             1        results_1_64
# 1          64          64             3        results_3_64
# 2          64          64             6        results_6_64
# 3          64          64            11       results_11_64
# 4          64          64            20       results_20_64
# 5          64          64            37       results_37_64
# 6          64          64            67       results_67_64
# 7          64          64           124      results_124_64
# 8          64          64           226      results_226_64
# 9          64          64           414      results_414_64
# 10         64          64           757      results_757_64
# 11         64          64          1384     results_1384_64
# 12         64          64          2528     results_2528_64
# 13         64          64          4620     results_4620_64
# 14         64          64          8442     results_8442_64
# 15         64          64         15425    results_15425_64
# 16         64          64         28184    results_28184_64
# 17         64          64         51496    results_51496_64
# 18         64          64         94089    results_94089_64
# 19         64          64        171911   results_171911_64
# 20         64          64        314101   results_314101_64
# 21         64          64        573897   results_573897_64
# 22         64          64       1048576  results_1048576_64

# %%
# Set the aesthetics for the plot
sns.set(style="whitegrid")

# Create the scatter plot
plt.figure(figsize=(10, 6))
ax = sns.scatterplot(data=tasks_df, x='payload_size', y='num_users', size='num_users', hue='num_users', palette='viridis', sizes=(20, 200))

# Set the scale of the x/y-axis to logarithmic to better visualize the data
ax.set_xscale('log', base=2)
ax.set_yscale('log', base=2)

# Set plot labels and title
ax.set_xlabel('Payload Size (Bytes)')
ax.set_ylabel('Number of Users')
ax.set_title('Number of Users vs Payload Size for Each Task')

# Show the plot
plt.show()

# %%
def run_benchmark_docker(task):
    results_file_path = f"results/{task['csv_filename']}"

    # Check if the results file already exists
    if os.path.exists(f".{results_file_path}_stats.csv"):
        print(f"Skipping benchmark for task: {task} as results already exist.")
        return
    
    # Set environment variables
    os.environ['NUM_USERS'] = str(task['num_users'])
    os.environ['SPAWN_RATE'] = str(task['spawn_rate'])
    os.environ['RUN_TIME'] = str(run_time_seconds)
    os.environ['CSV_FILENAME'] = results_file_path
    os.environ['PAYLOAD_SIZE'] = str(task['payload_size'])
    os.environ['NUM_WORKERS'] = str(num_workers)
    
    # Run the benchmark using Docker Compose
    subprocess.run(["docker", "compose", "up", "--scale", f"locust-worker={num_workers}"], check=True)

    # Optionally, you can stop and remove containers if needed
    subprocess.run(["docker-compose", "down"], check=True)


# Ensure the results directory exists
os.makedirs('.results', exist_ok=True)

#for task in tasks:
#    run_benchmark_docker(task)

# %%
def run_benchmark_local(task):
    results_file_path = f".results/{task['csv_filename']}"

    # Check if the results file already exists
    if os.path.exists(f"{results_file_path}_stats.csv"):
        print(f"Skipping benchmark for task: {task} as results already exist.")
        return
    
    os.environ['PAYLOAD_SIZE'] = str(task['payload_size'])
    os.environ['NUM_WORKERS'] = str(num_workers)
    
    # Command to start the Locust master
    master_command = ["locust", "-f", "../locust/locustfile.py", "--master", "--headless", 
                      "--expect-workers", "4",
                      "--host", "http://192.168.1.105:8000", 
                      "-u", str(task['num_users']), 
                      "-r", str(task['spawn_rate']), 
                      "--run-time", str(run_time_seconds),
                      "--csv", results_file_path]

    # Commands to start Locust workers
    worker_commands = [
        ["locust", "-f", "../locust/locustfile.py", "--worker", "--master-host", "127.0.0.1"] for _ in range(num_workers)
    ]

    # Start the Locust master
    master_process = subprocess.Popen(master_command)

    # Start the worker processes
    worker_processes = [subprocess.Popen(cmd) for cmd in worker_commands]
    
    try:
        # Wait for the master process to complete
        master_process.wait()
    except KeyboardInterrupt:
        # Handle Ctrl+C
        pass
    finally:
        # Terminate all processes
        master_process.terminate()
        for worker in worker_processes:
            worker.terminate()


# Ensure the results directory exists
os.makedirs('.results', exist_ok=True)

for task in tasks:
    run_benchmark_local(task)
# Out:
# payload_size: 1
# payload_size: 1payload_size: 1
#
# payload_size: 1
# payload_size: 1
# [2023-11-12 20:57:36,426] BUD-MAC-16300-(26473)/INFO/root: Waiting for workers to be ready, 0 of 4 connected
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# [2023-11-12 20:57:36,432] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_0b7fdb069b224fdf81439c2048111b7c (index 0) reported as ready. 1 workers connected.
# [2023-11-12 20:57:36,433] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_0b5c1fe4d36c4ca19a5143324c48b982 (index 1) reported as ready. 2 workers connected.
# [2023-11-12 20:57:36,433] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_25bdf1e78e14428eaef9beb3189604c3 (index 2) reported as ready. 3 workers connected.
# [2023-11-12 20:57:36,433] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_e85fa667251d4bba82b61a32a2e05740 (index 3) reported as ready. 4 workers connected.
# [2023-11-12 20:57:36,435] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:57:36,435] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:57:36,436] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:57:36,436] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:57:37,429] BUD-MAC-16300-(26473)/INFO/locust.main: Run time limit set to 30 seconds
# [2023-11-12 20:57:37,429] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:57:37,430] BUD-MAC-16300-(26473)/INFO/locust.runners: Sending spawn jobs of 64 users at 64.00 spawn rate to 4 ready workers
# [2023-11-12 20:57:37,550] BUD-MAC-16300-(26473)/INFO/locust.runners: All users spawned: {"StorageUser": 64} (64 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1387     0(0.00%) |     85       4     354     79 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1387     0(0.00%) |     85       4     354     79 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1387     0(0.00%) |     85       4     354     79 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1387     0(0.00%) |     85       4     354     79 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3731     0(0.00%) |     82       4     354     74 |  607.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3731     0(0.00%) |     82       4     354     74 |  607.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               6104     0(0.00%) |     82       4     416     72 |  696.50        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      6104     0(0.00%) |     82       4     416     72 |  696.50        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               6104     0(0.00%) |     82       4     416     72 |  696.50        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      6104     0(0.00%) |     82       4     416     72 |  696.50        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               8446     0(0.00%) |     82       4     416     73 |  724.89        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      8446     0(0.00%) |     82       4     416     73 |  724.89        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              10751     0(0.00%) |     82       4     501     72 |  785.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     10751     0(0.00%) |     82       4     501     72 |  785.10        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              11915     0(0.00%) |     82       4     501     72 |  757.40        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     11915     0(0.00%) |     82       4     501     72 |  757.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              13072     0(0.00%) |     82       4     501     72 |  777.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     13072     0(0.00%) |     82       4     501     72 |  777.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              15429     0(0.00%) |     82       4     501     72 |  773.60        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     15429     0(0.00%) |     82       4     501     72 |  773.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              17746     0(0.00%) |     82       3     501     72 |  777.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     17746     0(0.00%) |     82       3     501     72 |  777.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              17746     0(0.00%) |     82       3     501     72 |  777.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     17746     0(0.00%) |     82       3     501     72 |  777.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              20113     0(0.00%) |     82       3     501     72 |  774.60        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     20113     0(0.00%) |     82       3     501     72 |  774.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              22422     0(0.00%) |     82       3     501     72 |  782.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     22422     0(0.00%) |     82       3     501     72 |  782.00        0.00
#
# [2023-11-12 20:58:07,429] BUD-MAC-16300-(26473)/INFO/locust.main: --run-time limit reached, shutting down
# [2023-11-12 20:58:07,430] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 20:58:07,430] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 20:58:07,430] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 20:58:07,430] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 20:58:07,435] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 20:58:07,435] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 20:58:07,435] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 20:58:07,435] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 20:58:07,435] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_0b5c1fe4d36c4ca19a5143324c48b982' (index 1) quit. 0 workers ready.
# [2023-11-12 20:58:07,436] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_25bdf1e78e14428eaef9beb3189604c3' (index 2) quit. 0 workers ready.
# [2023-11-12 20:58:07,436] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_e85fa667251d4bba82b61a32a2e05740' (index 3) quit. 0 workers ready.
# [2023-11-12 20:58:07,436] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_0b7fdb069b224fdf81439c2048111b7c' (index 0) quit. 0 workers ready.
# [2023-11-12 20:58:07,437] BUD-MAC-16300-(26473)/INFO/locust.runners: The last worker quit, stopping test.
# [2023-11-12 20:58:08,437] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              23170     0(0.00%) |     82       3     501     72 |  772.34        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     23170     0(0.00%) |     82       3     501     72 |  772.34        0.00
#
# Response time percentiles (approximated)
# Type     Name                                                                                  50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
# PUT      /                                                                                      72     91    110    120    150    180    230    260    370    460    500  23170
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated                                                                             72     91    110    120    150    180    230    260    370    460    500  23170
# payload_size: 3
# payload_size: 3
# payload_size: 3
# payload_size: 3
# payload_size: 3
# [2023-11-12 20:58:09,585] BUD-MAC-16300-(26473)/INFO/root: Waiting for workers to be ready, 0 of 4 connected
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# [2023-11-12 20:58:09,588] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_25ddc26e75224df48287e29d9d50f754 (index 0) reported as ready. 1 workers connected.
# [2023-11-12 20:58:09,588] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_27a0de7554fa41cda9ee1d4311c08d5d (index 1) reported as ready. 2 workers connected.
# [2023-11-12 20:58:09,589] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_beb6ad3c390c4ba3b2e1fc86ad6cb54d (index 2) reported as ready. 3 workers connected.
# [2023-11-12 20:58:09,590] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:58:09,590] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:58:09,590] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:58:09,596] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_417c93af683b4a68b33fe52387ffa05b (index 3) reported as ready. 4 workers connected.
# [2023-11-12 20:58:09,598] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:58:10,589] BUD-MAC-16300-(26473)/INFO/locust.main: Run time limit set to 30 seconds
# [2023-11-12 20:58:10,589] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:58:10,593] BUD-MAC-16300-(26473)/INFO/locust.runners: Sending spawn jobs of 64 users at 64.00 spawn rate to 4 ready workers
# [2023-11-12 20:58:10,674] BUD-MAC-16300-(26473)/INFO/locust.runners: All users spawned: {"StorageUser": 64} (64 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1386     0(0.00%) |     85       4     333     79 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1386     0(0.00%) |     85       4     333     79 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3166     0(0.00%) |     83       4     333     73 |  540.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3166     0(0.00%) |     83       4     333     73 |  540.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3742     0(0.00%) |     83       4     333     72 |  567.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3742     0(0.00%) |     83       4     333     72 |  567.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               6074     0(0.00%) |     82       4     416     74 |  674.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      6074     0(0.00%) |     82       4     416     74 |  674.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               7806     0(0.00%) |     82       4     416     73 |  701.22        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      7806     0(0.00%) |     82       4     416     73 |  701.22        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               8427     0(0.00%) |     82       4     416     73 |  710.56        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      8427     0(0.00%) |     82       4     416     73 |  710.56        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              10758     0(0.00%) |     82       4     416     72 |  778.20        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     10758     0(0.00%) |     82       4     416     72 |  778.20        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              12507     0(0.00%) |     82       4     433     72 |  771.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     12507     0(0.00%) |     82       4     433     72 |  771.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              13115     0(0.00%) |     82       4     433     71 |  780.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     13115     0(0.00%) |     82       4     433     71 |  780.10        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              15453     0(0.00%) |     82       3     433     71 |  781.50        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     15453     0(0.00%) |     82       3     433     71 |  781.50        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              17213     0(0.00%) |     82       3     433     72 |  771.80        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     17213     0(0.00%) |     82       3     433     72 |  771.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              17799     0(0.00%) |     82       3     433     72 |  778.60        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     17799     0(0.00%) |     82       3     433     72 |  778.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              20114     0(0.00%) |     82       3     450     71 |  780.70        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     20114     0(0.00%) |     82       3     450     71 |  780.70        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              22465     0(0.00%) |     81       3     450     71 |  779.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     22465     0(0.00%) |     81       3     450     71 |  779.30        0.00
#
# [2023-11-12 20:58:40,591] BUD-MAC-16300-(26473)/INFO/locust.main: --run-time limit reached, shutting down
# [2023-11-12 20:58:40,591] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 20:58:40,592] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 20:58:40,592] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 20:58:40,592] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 20:58:40,597] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 20:58:40,597] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 20:58:40,597] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 20:58:40,597] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_25ddc26e75224df48287e29d9d50f754' (index 0) quit. 0 workers ready.
# [2023-11-12 20:58:40,597] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 20:58:40,597] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_beb6ad3c390c4ba3b2e1fc86ad6cb54d' (index 2) quit. 0 workers ready.
# [2023-11-12 20:58:40,598] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_417c93af683b4a68b33fe52387ffa05b' (index 3) quit. 0 workers ready.
# [2023-11-12 20:58:40,598] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_27a0de7554fa41cda9ee1d4311c08d5d' (index 1) quit. 0 workers ready.
# [2023-11-12 20:58:40,598] BUD-MAC-16300-(26473)/INFO/locust.runners: The last worker quit, stopping test.
# [2023-11-12 20:58:41,601] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              23208     0(0.00%) |     82       3     450     71 |  773.73        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     23208     0(0.00%) |     82       3     450     71 |  773.73        0.00
#
# Response time percentiles (approximated)
# Type     Name                                                                                  50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
# PUT      /                                                                                      71     91    110    120    150    180    230    270    360    420    450  23208
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated                                                                             71     91    110    120    150    180    230    270    360    420    450  23208
# payload_size: 6
# payload_size: 6
# payload_size: 6
# payload_size: 6
# payload_size: 6
# [2023-11-12 20:58:42,720] BUD-MAC-16300-(26473)/INFO/root: Waiting for workers to be ready, 0 of 4 connected
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# [2023-11-12 20:58:42,723] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_2cd2c681957b48f8ab4a017f636201ac (index 0) reported as ready. 1 workers connected.
# [2023-11-12 20:58:42,725] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:58:42,729] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_b3113fe1204845ddaef8611be7fef0dc (index 1) reported as ready. 2 workers connected.
# [2023-11-12 20:58:42,730] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_943bcff615704142935b7764ed741f91 (index 2) reported as ready. 3 workers connected.
# [2023-11-12 20:58:42,731] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:58:42,731] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:58:42,738] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker BUD-MAC-16300-(26473)_bc3eb10d053045ebadc1206a0b6be9d8 (index 3) reported as ready. 4 workers connected.
# [2023-11-12 20:58:42,739] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:58:43,726] BUD-MAC-16300-(26473)/INFO/locust.main: Run time limit set to 30 seconds
# [2023-11-12 20:58:43,726] BUD-MAC-16300-(26473)/INFO/locust.main: Starting Locust 2.18.1
# [2023-11-12 20:58:43,727] BUD-MAC-16300-(26473)/INFO/locust.runners: Sending spawn jobs of 64 users at 64.00 spawn rate to 4 ready workers
# [2023-11-12 20:58:43,811] BUD-MAC-16300-(26473)/INFO/locust.runners: All users spawned: {"StorageUser": 64} (64 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1449     0(0.00%) |     81       4     332     71 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1449     0(0.00%) |     81       4     332     71 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2061     0(0.00%) |     80       4     332     70 |  499.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2061     0(0.00%) |     80       4     332     70 |  499.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3740     0(0.00%) |     82       4     332     71 |  542.33        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3740     0(0.00%) |     82       4     332     71 |  542.33        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               6083     0(0.00%) |     81       3     390     71 |  660.67        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      6083     0(0.00%) |     81       3     390     71 |  660.67        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               6677     0(0.00%) |     81       3     390     70 |  681.78        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      6677     0(0.00%) |     81       3     390     70 |  681.78        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               8448     0(0.00%) |     81       3     393     69 |  700.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      8448     0(0.00%) |     81       3     393     69 |  700.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              10737     0(0.00%) |     81       3     393     69 |  777.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     10737     0(0.00%) |     81       3     393     69 |  777.90        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              11351     0(0.00%) |     81       3     393     70 |  763.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     11351     0(0.00%) |     81       3     393     70 |  763.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              13046     0(0.00%) |     81       3     393     70 |  777.40        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     13046     0(0.00%) |     81       3     393     70 |  777.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              15342     0(0.00%) |     81       3     448     69 |  770.70        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     15342     0(0.00%) |     81       3     448     69 |  770.70        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                              16537     0(0.00%) |     81       3     448     70 |  760.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                     16537     0(0.00%) |     81       3     448     70 |  760.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# ...
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                137     1(0.73%) |    703     194    1478    560 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       137     1(0.73%) |    703     194    1478    560 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                220     1(0.45%) |    655     194    1478    560 |   47.00        0.33
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       220     1(0.45%) |    655     194    1478    560 |   47.00        0.33
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                476     1(0.21%) |    611     194    1478    550 |   51.33        0.33
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       476     1(0.21%) |    611     194    1478    550 |   51.33        0.33
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                                796     1(0.13%) |    597     194    1478    560 |   82.67        0.17
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                       796     1(0.13%) |    597     194    1478    560 |   82.67        0.17
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1140     1(0.09%) |    586     194    1478    560 |   92.56        0.11
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1140     1(0.09%) |    586     194    1478    560 |   92.56        0.11
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1140     1(0.09%) |    586     194    1478    560 |   92.56        0.11
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1140     1(0.09%) |    586     194    1478    560 |   92.56        0.11
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1479     1(0.07%) |    581     194    1478    560 |  112.40        0.10
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1479     1(0.07%) |    581     194    1478    560 |  112.40        0.10
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1805     1(0.06%) |    581     194    1478    560 |  110.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1805     1(0.06%) |    581     194    1478    560 |  110.10        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               1805     1(0.06%) |    581     194    1478    560 |  110.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      1805     1(0.06%) |    581     194    1478    560 |  110.10        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2137     1(0.05%) |    580     172    1478    560 |  110.70        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2137     1(0.05%) |    580     172    1478    560 |  110.70        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2445     1(0.04%) |    581     172    1478    560 |  109.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2445     1(0.04%) |    581     172    1478    560 |  109.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2445     1(0.04%) |    581     172    1478    560 |  109.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2445     1(0.04%) |    581     172    1478    560 |  109.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               2796     1(0.04%) |    579     172    1478    560 |  109.40        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      2796     1(0.04%) |    579     172    1478    560 |  109.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3116     1(0.03%) |    579     172    1478    560 |  109.90        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3116     1(0.03%) |    579     172    1478    560 |  109.90        0.00
#
# [2023-11-12 21:10:17,797] BUD-MAC-16300-(26473)/INFO/locust.main: --run-time limit reached, shutting down
# [2023-11-12 21:10:17,801] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 21:10:17,802] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 21:10:17,802] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 21:10:17,805] BUD-MAC-16300-(26473)/INFO/locust.runners: Got quit message from master, shutting down...
# [2023-11-12 21:10:17,806] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 21:10:17,806] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_7c01923952564586adacb68826ec97c0' (index 0) quit. 0 workers ready.
# [2023-11-12 21:10:17,807] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 21:10:17,807] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_7cc2a3aa6426465cadfd0c2c8faf2a4c' (index 2) quit. 0 workers ready.
# [2023-11-12 21:10:17,810] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 21:10:17,810] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_ef3fda1b699e44e8a2e50d70ddd5c16c' (index 1) quit. 0 workers ready.
# [2023-11-12 21:10:17,815] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 0)
# [2023-11-12 21:10:17,815] BUD-MAC-16300-(26473)/INFO/locust.runners: Worker 'BUD-MAC-16300-(26473)_60a921183e844c1391f481cecae2cf03' (index 3) quit. 0 workers ready.
# [2023-11-12 21:10:17,816] BUD-MAC-16300-(26473)/INFO/locust.runners: The last worker quit, stopping test.
# [2023-11-12 21:10:18,801] BUD-MAC-16300-(26473)/INFO/locust.main: Shutting down (exit code 1)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# PUT      /                                                                               3224     1(0.03%) |    580     172    1478    560 |  107.44        0.03
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                      3224     1(0.03%) |    580     172    1478    560 |  107.44        0.03
#
# Response time percentiles (approximated)
# Type     Name                                                                                  50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
# PUT      /                                                                                     560    610    640    670    750    820    970   1100   1400   1500   1500   3224
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated                                                                            560    610    640    670    750    820    970   1100   1400   1500   1500   3224
#
# Error report
# # occurrences      Error
# ------------------|---------------------------------------------------------------------------------------------------------------------------------------------
# 1                  PUT /: "HTTPError('500 Server Error: Internal Server Error for url: /')"
# ------------------|---------------------------------------------------------------------------------------------------------------------------------------------

# %%
results = []
for task in tasks:
    csv_filename = f".results/{task['csv_filename']}_stats.csv"
    try:
        df = pd.read_csv(csv_filename)
        if not df.empty:
            agg_row = df.iloc[-1]  # Select the last row
            if agg_row["Name"] == "Aggregated":
                results.append({
                    "payload_size": task["payload_size"],
                    "num_users": task["num_users"],
                    "total_requests": int(agg_row["Request Count"]),
                    "avg_response_time": float(agg_row["Average Response Time"]),
                    "med_response_time": float(agg_row["Median Response Time"]),
                })
            else:
                print(f"No aggregated data found in {csv_filename}")
        else:
            print(f"The CSV file is empty: {csv_filename}")
    except FileNotFoundError:
        print(f"Results not found for task: {task}")
    except Exception as e:
        print(f"An error occurred for task {task}: {str(e)}")

results_df = pd.DataFrame(results)
pd.set_option('display.max_rows', None)
print(results_df)
pd.reset_option('display.max_rows')
# Out:
#     payload_size  num_users  total_requests  avg_response_time  \
# 0              1         64           23170          82.291454
# 1              3         64           23208          82.039881
# 2              6         64           23024          80.958100
# 3             11         64           23057          82.788640
# 4             20         64           22907          83.393632
# 5             37         64           23121          81.364880
# 6             67         64           22822          81.231510
# 7            124         64           22976          83.178584
# 8            226         64           23192          78.415842
# 9            414         64           23010          81.879778
# 10           757         64           23024          82.162655
# 11          1384         64           22778          83.887020
# 12          2528         64           22669          81.544179
# 13          4620         64           22739          82.190922
# 14          8442         64           22437          83.824361
# 15         15425         64           21909          82.511196
# 16         28184         64           21224          88.983630
# 17         51496         64           20299          94.028317
# 18         94089         64           17761         107.401257
# 19        171911         64            8044         235.766685
# 20        314101         64            6789         278.938691
# 21        573897         64            4976         369.000515
# 22       1048576         64            3224         580.257201
#
#     med_response_time
# 0                72.0
# 1                71.0
# 2                70.0
# 3                71.0
# 4                72.0
# 5                72.0
# 6                69.0
# 7                72.0
# 8                68.0
# 9                70.0
# 10               71.0
# 11               72.0
# 12               72.0
# 13               69.0
# 14               72.0
# 15               76.0
# 16               80.0
# 17               85.0
# 18               98.0
# 19              210.0
# 20              250.0
# 21              340.0
# 22              560.0

# %%
# Add columns for requests per second and requests per second
results_df['requests_per_second'] = results_df['total_requests'] / run_time_seconds / 1000

#results_df['avg_response_time_per_user'] = results_df['avg_response_time'] / results_df['num_users']
results_df['med_response_time_per_user'] = results_df['med_response_time'] / results_df['num_users']
results_df['throughput'] = results_df['total_requests'] / run_time_seconds * results_df['payload_size'] / 1024 / 1024 # MB/s

# Pivot the DataFrames for the heatmaps
heatmap_data_rps = results_df.pivot(index="payload_size", columns="num_users", values="requests_per_second")
heatmap_data_rt = results_df.pivot(index="payload_size", columns="num_users", values="throughput")

# Set up the matplotlib figure
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 8))

# Draw the heatmap for average response time
sns.heatmap(heatmap_data_rps, cmap="viridis", annot=True, fmt=".2f", linewidths=.5, cbar_kws={"label": "1000 Requests per Second"}, ax=axes[0])
axes[0].set_title('1000 Requests per Second')
axes[0].set_xlabel('Number of Users')
axes[0].set_ylabel('Payload Size (Bytes)')

# Draw the heatmap for requests per second per user
log_heatmap_data = np.log2(heatmap_data_rt + 1e-6)
sns.heatmap(log_heatmap_data, cmap="viridis", annot=True, fmt=".2f", linewidths=.5, cbar_kws={"label": "Throughput Log2(MB/s)"}, ax=axes[1])
axes[1].set_title('Throughput')
axes[1].set_xlabel('Number of Users')
axes[1].set_ylabel('Payload Size (Bytes)')

plt.tight_layout()
plt.show()

# %%
print( results_df['num_users'])
# Out:
# 0     64
# 1     64
# 2     64
# 3     64
# 4     64
# 5     64
# 6     64
# 7     64
# 8     64
# 9     64
# 10    64
# 11    64
# 12    64
# 13    64
# 14    64
# 15    64
# 16    64
# 17    64
# 18    64
# 19    64
# 20    64
# 21    64
# 22    64
# Name: num_users, dtype: int64

# %%
# Assuming 'results_df' is your DataFrame

# First, we will group the data by 'payload_size' and calculate the mean 'total_requests' and 'avg_response_time'.
# This is necessary because your data seems to have multiple entries for each 'payload_size'.
grouped = results_df.groupby('payload_size').mean().reset_index()

# Now let's plot the data
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set the x-axis label
ax1.set_xlabel('Payload Size (bytes)', fontsize=14)

# Plot the 'total_requests' on the left y-axis
ax1.set_ylabel('Total Requests', color='tab:blue', fontsize=14)
ax1.plot(grouped['payload_size'], grouped['total_requests'], color='tab:blue', label='Total Requests')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis to share the same x-axis
ax2 = ax1.twinx()  
ax2.set_ylabel('Average Response Time (ms)', color='tab:red', fontsize=14)  # we already handled the x-label with ax1
ax2.plot(grouped['payload_size'], grouped['avg_response_time'], color='tab:red', label='Average Response Time')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Set the title of the plot
plt.title('Total Requests and Average Response Time by Payload Size', fontsize=16)

# Show a legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.show()
